# %% [markdown]
# # Influence optical parameters on the LCE

# %%
## Imports:

import numpy as np
import matplotlib
from matplotlib.colors import LogNorm
from matplotlib.ticker import AutoMinorLocator
import matplotlib.pyplot as plt
from matplotlib import gridspec            # to arrange the plots nicely
# %matplotlib inline

import uproot                              # uproot for easy import of ROOT tree contents
import collections                         # used for named tuples
import pandas as pd
import math

# %%
#! ls ../../Xebra_G4/*.root

# %%
#filename = '../../Xebra_G4/optPhot_1e6_noscint_R095_L040.root'

# %%
'''branches= ['xp_pri','yp_pri','zp_pri','nbpmthits','ntpmthits','pmthits'] # Be careful that the branches are also initilized in _chunk_collect

import concurrent.futures
executor = concurrent.futures.ThreadPoolExecutor(8)

_chunk_collect = pd.DataFrame({'xp_pri' : [],'yp_pri' : [],'zp_pri' : [],'nbpmthits' : [],'ntpmthits' : [],'pmthits' : []}) # Initialize empty data frame

for _chunk in uproot.iterate(filename, "events/events",branches, entrysteps=100000, outputtype=pd.DataFrame, executor=executor):
    _chunk.columns=branches
    _chunk_collect = _chunk_collect.append(_chunk)

# starting position photons
xp_pri = _chunk_collect.xp_pri
yp_pri = _chunk_collect.yp_pri
zp_pri = _chunk_collect.zp_pri
nphotons = len(xp_pri)

# bottom PMT hits count
nbpmthits = _chunk_collect.nbpmthits
nbpmthits_sum = sum(nbpmthits)

# top PMT hits count
ntpmthits = _chunk_collect.ntpmthits
ntpmthits_sum = sum(ntpmthits)

# total PMT hits count
napmthits = nbpmthits+ntpmthits
napmthits_sum = sum(napmthits)
pmthits = _chunk_collect.pmthits''';

# %%
'''pmthits_sums = [0]*8
for i in range(0,8):
    pmthits_sums[i] = sum(nth_tuple_subentries(pmthits, i))''';

# %%
'''print(nphotons)
print(pmthits_sums)
print(napmthits_sum)
print(napmthits_sum/nphotons)''';

# %%
QE_PMT0 = 0.325
QE_PMT1 = 0.3
QE_PMT2 = 0.3
QE_PMT3 = 0.3
QE_PMT4 = 0.3
QE_PMT5 = 0.3
QE_PMT6 = 0.3
QE_PMT7 = 0.3
QE_Bottom = QE_PMT0
QE_Top = 0.3

CE_PMT0 = 0.95
CE_PMT1 = 0.7
CE_PMT2 = 0.7
CE_PMT3 = 0.7
CE_PMT4 = 0.7
CE_PMT5 = 0.7
CE_PMT6 = 0.7
CE_PMT7 = 0.7
CE_Bottom = CE_PMT0
CE_Top = 0.7

W = 1/(1302.808447/32.1517) # 1/W = photons/keV @ 32.1517 keV, 500 V/cm, ER
print('1/W  = '+str(1/W)+' ph/keV')
We = 1/(1045.457843/32.1517) # 1/W = electrons/keV @ 32.1517 keV, 500 V/cm, ER
print('1/We = '+str(1/We)+' e/keV')

W0 = 1/(2195.519/32.1517) # 1/W = photons/keV @ 32.1517 keV, 0.0001 V/cm, ER
print('1/W0  = '+str(1/W0)+' ph/keV')
# Out:
# 1/W  = 40.52067066438166 ph/keV
# 1/We = 32.51640949001141 e/keV
# 1/W0  = 68.28624924965087 ph/keV

# %%
# 8      0.40           100.0  1000000.0         98416.0          2407.0
# 9      0.30           100.0  1000000.0         86603.0          2182.0
#
#    pmthits_sums_2  pmthits_sums_3  pmthits_sums_4  pmthits_sums_5  \
# 0          7376.0          5691.0          5703.0          7332.0
# ...

# %% [markdown]
# #### Current benchmark numbers

# %%
L = 20
R = 0.95

print('L_(abs,LXe) = '+str(L)+' cm')
print('R_(PTFE) = '+str(100*R)+' %\n')

LCE = np.mean(opticals["LCE"][opticals["LXe_abs_len_cm"] == L][opticals["PTFE_ref"] == R])
print('LCE'+' = '+str(round(100*LCE,1))+' %')

DE = np.mean(opticals["DE"][opticals["LXe_abs_len_cm"] == L][opticals["PTFE_ref"] == R])
print('DE'+'  =  '+str(round(100*DE,1))+' %')

LY = np.mean(opticals["LY"][opticals["LXe_abs_len_cm"] == L][opticals["PTFE_ref"] == R])
print('LY'+'  =  '+str(round(LY,1))+' pe/keV')
# Out:
# L_(abs,LXe) = 20 cm
# R_(PTFE) = 95.0 %
#
# LCE = 18.1 %
# DE  =  5.3 %
# LY  =  2.2 pe/keV

# %%
L = 100
R = 0.95

print('L_(abs,LXe) = '+str(L)+' cm')
print('R_(PTFE) = '+str(100*R)+' %\n')

LCE = np.mean(opticals["LCE"][opticals["LXe_abs_len_cm"] == L][opticals["PTFE_ref"] == R])
print('LCE'+' = '+str(round(100*LCE,1))+' %')

DE = np.mean(opticals["DE"][opticals["LXe_abs_len_cm"] == L][opticals["PTFE_ref"] == R])
print('DE'+'  =  '+str(round(100*DE,1))+' %')

LY = np.mean(opticals["LY"][opticals["LXe_abs_len_cm"] == L][opticals["PTFE_ref"] == R])
print('LY'+'  =  '+str(round(LY,1))+' pe/keV')
# Out:
# L_(abs,LXe) = 100 cm
# R_(PTFE) = 95.0 %
#
# LCE = 29.7 %
# DE  =  8.8 %
# LY  =  3.6 pe/keV

# %%
L = 100
R = 0.99

print('L_(abs,LXe) = '+str(L)+' cm')
print('R_(PTFE) = '+str(100*R)+' %\n')

LCE = np.mean(opticals["LCE"][opticals["LXe_abs_len_cm"] == L][opticals["PTFE_ref"] == R])
print('LCE'+' = '+str(round(100*LCE,1))+' %')

DE = np.mean(opticals["DE"][opticals["LXe_abs_len_cm"] == L][opticals["PTFE_ref"] == R])
print('DE'+'  =  '+str(round(100*DE,1))+' %')

LY = np.mean(opticals["LY"][opticals["LXe_abs_len_cm"] == L][opticals["PTFE_ref"] == R])
print('LY'+'  =  '+str(round(LY,1))+' pe/keV')
# Out:
# L_(abs,LXe) = 100 cm
# R_(PTFE) = 99.0 %
#
# LCE = 32.9 %
# DE  =  9.7 %
# LY  =  3.9 pe/keV

# %%
#############################################
## Set plot styles:
#############################################

fig=plt.figure(figsize=(16, 10), dpi=150)

# Text options
plt.rc('text', usetex=True)
plt.rc('font', family='serif')

# Labels
label_size = 32.5 #25
label_pad = 13 #10
title_size = 39 #30
title_pad = 26 #20

# Axes Parameters
axes = plt.gca()
axes.tick_params(axis='both') 

# Axes ---> Linewidth
for axis in ['top','bottom','left','right']:
    axes.spines[axis].set_linewidth(2.2)
    
# Axes ---> Ticks
axes.xaxis.set_minor_locator(AutoMinorLocator(5)) 
plt.tick_params(which='minor', direction='in', labelsize=label_size, top=True, right=True, width=1.2, length=6)
axes.yaxis.set_minor_locator(AutoMinorLocator(5))
plt.tick_params(which='minor', direction='in', labelsize=label_size, top=True, right=True, width=1.2, length=6)
plt.tick_params(which='major', direction='in', labelsize=label_size, top=True, right=True, width=1.2, length=12)

# Grid
plt.grid(True)
    
#############################################
## Plot specific settings and plot data
#############################################

# Data plot
x = opticals["PTFE_ref"][opticals["LXe_abs_len_cm"] == 100]
y = opticals["LCE"][opticals["LXe_abs_len_cm"] == 100]
plt.scatter(x,y, label = "100 cm", color = "blue", s = 80)

x = opticals["PTFE_ref"][opticals["LXe_abs_len_cm"] == 20]
y = opticals["LCE"][opticals["LXe_abs_len_cm"] == 20]
plt.scatter(x,y, label = "20 cm", color = "red", s = 80)

plt.xlabel('PTFE Reflectivity', fontsize = label_size, labelpad = label_pad)
plt.ylabel('Average LCE', fontsize = label_size, labelpad = label_pad)
plt.title('Influence of the PTFE Reflectivity on the LCE', fontsize = title_size, pad = title_pad)

# Legend
leg = plt.legend(loc=2, bbox_to_anchor=(0.01,0.99), title="LXe absorption length", fontsize=0.9*label_size, frameon=True, shadow=False, edgecolor='black', fancybox=False)
leg.get_title().set_fontsize(0.9*label_size)
for line in leg.get_lines(): # enumerated
    line.set_linewidth(4)
leg.get_frame().set_linewidth(2.5)
leg._legend_box.align = "left"

# Axes ---> Range
#plt.xlim(0,100)
#plt.ylim(0.02,0.104)
#plt.xlim(left=0)
#plt.yscale('log', nonposy='clip')

fig.savefig("Influence_TeflonRef_LCE.png")
plt.show()

# %%
#############################################
## Set plot styles:
#############################################

fig=plt.figure(figsize=(16, 10), dpi=150)

# Text options
plt.rc('text', usetex=True)
plt.rc('font', family='serif')

# Labels
label_size = 32.5 #25
label_pad = 13 #10
title_size = 39 #30
title_pad = 26 #20

# Axes Parameters
axes = plt.gca()
axes.tick_params(axis='both') 

# Axes ---> Linewidth
for axis in ['top','bottom','left','right']:
    axes.spines[axis].set_linewidth(2.2)
    
# Axes ---> Ticks
axes.xaxis.set_minor_locator(AutoMinorLocator(5)) 
plt.tick_params(which='minor', direction='in', labelsize=label_size, top=True, right=True, width=1.2, length=6)
axes.yaxis.set_minor_locator(AutoMinorLocator(5))
plt.tick_params(which='minor', direction='in', labelsize=label_size, top=True, right=True, width=1.2, length=6)
plt.tick_params(which='major', direction='in', labelsize=label_size, top=True, right=True, width=1.2, length=12)

# Grid
plt.grid(True)
    
#############################################
## Plot specific settings and plot data
#############################################

# Data plot
x = opticals["PTFE_ref"][opticals["LXe_abs_len_cm"] == 100]
y = opticals["DE"][opticals["LXe_abs_len_cm"] == 100]
plt.scatter(x,y, label = "100 cm", color = "blue", s = 80)

x = opticals["PTFE_ref"][opticals["LXe_abs_len_cm"] == 20]
y = opticals["DE"][opticals["LXe_abs_len_cm"] == 20]
plt.scatter(x,y, label = "20 cm", color = "red", s = 80)

plt.xlabel('PTFE Reflectivity', fontsize = label_size, labelpad = label_pad)
plt.ylabel('Average DE', fontsize = label_size, labelpad = label_pad)
plt.title('Influence of the PTFE Reflectivity on the DE', fontsize = title_size, pad = title_pad)

# Legend
leg = plt.legend(loc=2, bbox_to_anchor=(0.01,0.99), title="LXe absorption length", fontsize=0.9*label_size, frameon=True, shadow=False, edgecolor='black', fancybox=False)
leg.get_title().set_fontsize(0.9*label_size)
for line in leg.get_lines(): # enumerated
    line.set_linewidth(4)
leg.get_frame().set_linewidth(2.5)
leg._legend_box.align = "left"

# Axes ---> Range
#plt.xlim(0,100)
#plt.ylim(0.02,0.104)
#plt.xlim(left=0)
#plt.yscale('log', nonposy='clip')

fig.savefig("Influence_TeflonRef_DE.png")
plt.show()

# %%
#############################################
## Set plot styles:
#############################################

fig=plt.figure(figsize=(16, 10), dpi=150)

# Text options
plt.rc('text', usetex=True)
plt.rc('font', family='serif')

# Labels
label_size = 32.5 #25
label_pad = 13 #10
title_size = 39 #30
title_pad = 26 #20

# Axes Parameters
axes = plt.gca()
axes.tick_params(axis='both') 

# Axes ---> Linewidth
for axis in ['top','bottom','left','right']:
    axes.spines[axis].set_linewidth(2.2)
    
# Axes ---> Ticks
axes.xaxis.set_minor_locator(AutoMinorLocator(5)) 
plt.tick_params(which='minor', direction='in', labelsize=label_size, top=True, right=True, width=1.2, length=6)
axes.yaxis.set_minor_locator(AutoMinorLocator(5))
plt.tick_params(which='minor', direction='in', labelsize=label_size, top=True, right=True, width=1.2, length=6)
plt.tick_params(which='major', direction='in', labelsize=label_size, top=True, right=True, width=1.2, length=12)

# Grid
plt.grid(True)
    
#############################################
## Plot specific settings and plot data
#############################################

# Data plot
x = opticals["PTFE_ref"][opticals["LXe_abs_len_cm"] == 100]
y = opticals["LY"][opticals["LXe_abs_len_cm"] == 100]
plt.scatter(x,y, label = "100 cm", color = "blue", s = 80)

x = opticals["PTFE_ref"][opticals["LXe_abs_len_cm"] == 20]
y = opticals["LY"][opticals["LXe_abs_len_cm"] == 20]
plt.scatter(x,y, label = "20 cm", color = "red", s = 80)

plt.xlabel('PTFE Reflectivity', fontsize = label_size, labelpad = label_pad)
plt.ylabel('Average LY [pe/keV]', fontsize = label_size, labelpad = label_pad)
plt.title('Influence of the PTFE Reflectivity on the LY', fontsize = title_size, pad = title_pad)

# Legend
leg = plt.legend(loc=2, bbox_to_anchor=(0.01,0.99), title="W$^{-1}$ = "+str(round(1/W,2))+" ph/keV,\n"+"LXe absorption length:", fontsize=0.9*label_size, frameon=True, shadow=False, edgecolor='black', fancybox=False)
leg.get_title().set_fontsize(0.9*label_size)
for line in leg.get_lines(): # enumerated
    line.set_linewidth(4)
leg.get_frame().set_linewidth(2.5)
leg._legend_box.align = "left"

# Axes ---> Range
#plt.xlim(0,100)
#plt.ylim(0.02,0.104)
#plt.xlim(left=0)
#plt.yscale('log', nonposy='clip')

fig.savefig("Influence_TeflonRef_LY.png")
plt.show()

# %%
#############################################
## Set plot styles:
#############################################

fig=plt.figure(figsize=(16, 10), dpi=150)

# Text options
plt.rc('text', usetex=True)
plt.rc('font', family='serif')

# Labels
label_size = 32.5 #25
label_pad = 13 #10
title_size = 39 #30
title_pad = 26 #20

# Axes Parameters
axes = plt.gca()
axes.tick_params(axis='both') 

# Axes ---> Linewidth
for axis in ['top','bottom','left','right']:
    axes.spines[axis].set_linewidth(2.2)
    
# Axes ---> Ticks
axes.xaxis.set_minor_locator(AutoMinorLocator(5)) 
plt.tick_params(which='minor', direction='in', labelsize=label_size, top=True, right=True, width=1.2, length=6)
axes.yaxis.set_minor_locator(AutoMinorLocator(5))
plt.tick_params(which='minor', direction='in', labelsize=label_size, top=True, right=True, width=1.2, length=6)
plt.tick_params(which='major', direction='in', labelsize=label_size, top=True, right=True, width=1.2, length=12)

# Grid
plt.grid(True)
    
#############################################
## Plot specific settings and plot data
#############################################

# Data plot
x = opticals["LXe_abs_len_cm"][opticals["PTFE_ref"] == 0.99]
y = opticals["LCE"][opticals["PTFE_ref"] == 0.99]
plt.scatter(x,y, label = "99 $\%$", color = "red", s = 80)

x = opticals["LXe_abs_len_cm"][opticals["PTFE_ref"] == 0.95]
y = opticals["LCE"][opticals["PTFE_ref"] == 0.95]
plt.scatter(x,y, label = "95 $\%$", color = "blue", s = 80)

plt.xlabel('LXe Absorption Length [cm]', fontsize = label_size, labelpad = label_pad)
plt.ylabel('Average LCE', fontsize = label_size, labelpad = label_pad)
plt.title('Influence of the LXe Absorption Length on the LCE', fontsize = title_size, pad = title_pad)

# Legend
leg = plt.legend(loc=4, bbox_to_anchor=(0.99,0.01), title="PTFE Reflectivity", fontsize=0.9*label_size, frameon=True, shadow=False, edgecolor='black', fancybox=False)
leg.get_title().set_fontsize(0.9*label_size)
for line in leg.get_lines(): # enumerated
    line.set_linewidth(4)
leg.get_frame().set_linewidth(2.5)
leg._legend_box.align = "left"

# Axes ---> Range
#plt.xlim(-20,520)
plt.ylim(0,0.4)
#plt.ylim(bottom=0)
#plt.xlim(left=0)
#plt.gca().set_xscale('log')

fig.savefig("Influence_LXeAbsLen_LCE.png")
plt.show()

# %%
#############################################
## Set plot styles:
#############################################

fig=plt.figure(figsize=(16, 10), dpi=150)

# Text options
plt.rc('text', usetex=True)
plt.rc('font', family='serif')

# Labels
label_size = 32.5 #25
label_pad = 13 #10
title_size = 39 #30
title_pad = 26 #20

# Axes Parameters
axes = plt.gca()
axes.tick_params(axis='both') 

# Axes ---> Linewidth
for axis in ['top','bottom','left','right']:
    axes.spines[axis].set_linewidth(2.2)
    
# Axes ---> Ticks
axes.xaxis.set_minor_locator(AutoMinorLocator(5)) 
plt.tick_params(which='minor', direction='in', labelsize=label_size, top=True, right=True, width=1.2, length=6)
axes.yaxis.set_minor_locator(AutoMinorLocator(5))
plt.tick_params(which='minor', direction='in', labelsize=label_size, top=True, right=True, width=1.2, length=6)
plt.tick_params(which='major', direction='in', labelsize=label_size, top=True, right=True, width=1.2, length=12)

# Grid
plt.grid(True)
    
#############################################
## Plot specific settings and plot data
#############################################

# Data plot
x = opticals["LXe_abs_len_cm"][opticals["PTFE_ref"] == 0.99]
y = opticals["DE"][opticals["PTFE_ref"] == 0.99]
plt.scatter(x,y, label = "99 $\%$", color = "red", s = 80)

x = opticals["LXe_abs_len_cm"][opticals["PTFE_ref"] == 0.95]
y = opticals["DE"][opticals["PTFE_ref"] == 0.95]
plt.scatter(x,y, label = "95 $\%$", color = "blue", s = 80)

plt.xlabel('LXe Absorption Length [cm]', fontsize = label_size, labelpad = label_pad)
plt.ylabel('Average DE', fontsize = label_size, labelpad = label_pad)
plt.title('Influence of the LXe Absorption Length on the DE', fontsize = title_size, pad = title_pad)

# Legend
leg = plt.legend(loc=4, bbox_to_anchor=(0.99,0.01), title="PTFE Reflectivity", fontsize=0.9*label_size, frameon=True, shadow=False, edgecolor='black', fancybox=False)
leg.get_title().set_fontsize(0.9*label_size)
for line in leg.get_lines(): # enumerated
    line.set_linewidth(4)
leg.get_frame().set_linewidth(2.5)
leg._legend_box.align = "left"

# Axes ---> Range
#plt.xlim(-20,520)
plt.ylim(0,0.12)
#plt.ylim(bottom=0)
#plt.xlim(left=0)
#plt.gca().set_xscale('log')

fig.savefig("Influence_LXeAbsLen_DE.png")
plt.show()

# %%
#############################################
## Set plot styles:
#############################################

fig=plt.figure(figsize=(16, 10), dpi=150)

# Text options
plt.rc('text', usetex=True)
plt.rc('font', family='serif')

# Labels
label_size = 32.5 #25
label_pad = 13 #10
title_size = 39 #30
title_pad = 26 #20

# Axes Parameters
axes = plt.gca()
axes.tick_params(axis='both') 

# Axes ---> Linewidth
for axis in ['top','bottom','left','right']:
    axes.spines[axis].set_linewidth(2.2)
    
# Axes ---> Ticks
axes.xaxis.set_minor_locator(AutoMinorLocator(5)) 
plt.tick_params(which='minor', direction='in', labelsize=label_size, top=True, right=True, width=1.2, length=6)
axes.yaxis.set_minor_locator(AutoMinorLocator(5))
plt.tick_params(which='minor', direction='in', labelsize=label_size, top=True, right=True, width=1.2, length=6)
plt.tick_params(which='major', direction='in', labelsize=label_size, top=True, right=True, width=1.2, length=12)

# Grid
plt.grid(True)
    
#############################################
## Plot specific settings and plot data
#############################################

# Data plot
x = opticals["LXe_abs_len_cm"][opticals["PTFE_ref"] == 0.99]
y = opticals["LY"][opticals["PTFE_ref"] == 0.99]
plt.scatter(x,y, label = "99 $\%$", color = "red", s = 80)

x = opticals["LXe_abs_len_cm"][opticals["PTFE_ref"] == 0.95]
y = opticals["LY"][opticals["PTFE_ref"] == 0.95]
plt.scatter(x,y, label = "95 $\%$", color = "blue", s = 80)

plt.xlabel('LXe Absorption Length [cm]', fontsize = label_size, labelpad = label_pad)
plt.ylabel('Average LY [pe/keV]', fontsize = label_size, labelpad = label_pad)
plt.title('Influence of the LXe Absorption Length on the LY', fontsize = title_size, pad = title_pad)

# Legend
leg = plt.legend(loc=4, bbox_to_anchor=(0.99,0.01), title="W$^{-1}$ = "+str(round(1/W,2))+" ph/keV,\n"+"PTFE Reflectivity:", fontsize=0.9*label_size, frameon=True, shadow=False, edgecolor='black', fancybox=False)
leg.get_title().set_fontsize(0.9*label_size)
for line in leg.get_lines(): # enumerated
    line.set_linewidth(4)
leg.get_frame().set_linewidth(2.5)
leg._legend_box.align = "left"

# Axes ---> Range
#plt.xlim(-20,520)
#plt.ylim(0,0.12)
plt.ylim(bottom=0)
#plt.xlim(left=0)
#plt.gca().set_xscale('log')

fig.savefig("Influence_LXeAbsLen_LY.png")
plt.show()

# %% [markdown]
# ### Influence transparency meshes

# %%
opticals = pd.DataFrame({'Transp_Mesh' : [], 'PTFE_ref' : [], 'LCE' : [], 'LY' : [], 'LY0' : []})
columns = ['Transp_Mesh', 'PTFE_ref', 'LCE', 'LY', 'LY0']

values = [0.89770509, 0.95, 29.8/100, 3.56, 5.99]
opticals = opticals.append(pd.DataFrame([np.array(values)], columns=columns), ignore_index=True)
values = [0.89770509, 0.99, 32.97/100, 3.94, 6.63]
opticals = opticals.append(pd.DataFrame([np.array(values)], columns=columns), ignore_index=True)
values = [0.93, 0.95, 33.44/100, 3.97, 6.7]
opticals = opticals.append(pd.DataFrame([np.array(values)], columns=columns), ignore_index=True)
values = [0.93, 0.99, 37.19/100, 4.42, 7.45]
opticals = opticals.append(pd.DataFrame([np.array(values)], columns=columns), ignore_index=True)
values = [0.999, 0.95, 45.08/100, 5.31, 8.94]
opticals = opticals.append(pd.DataFrame([np.array(values)], columns=columns), ignore_index=True)
values = [0.999, 0.99, 51.75/100, 6.09, 10.27]
opticals = opticals.append(pd.DataFrame([np.array(values)], columns=columns), ignore_index=True)
values = [0.80, 0.95, 22.09/100, 2.67, 4.49]
opticals = opticals.append(pd.DataFrame([np.array(values)], columns=columns), ignore_index=True)
values = [0.80, 0.99, 24.02/100, 2.90, 4.89]
opticals = opticals.append(pd.DataFrame([np.array(values)], columns=columns), ignore_index=True)
values = [0.97, 0.95, 39.29/100, 4.64, 7.83]
opticals = opticals.append(pd.DataFrame([np.array(values)], columns=columns), ignore_index=True)
values = [0.97, 0.99, 44.32/100, 5.24, 8.83]
opticals = opticals.append(pd.DataFrame([np.array(values)], columns=columns), ignore_index=True)
values = [0.85, 0.95, 25.50/100, 3.06, 5.16]
opticals = opticals.append(pd.DataFrame([np.array(values)], columns=columns), ignore_index=True)
values = [0.85, 0.99, 28.03/100, 3.37, 5.67]
opticals = opticals.append(pd.DataFrame([np.array(values)], columns=columns), ignore_index=True)

opticals
# Out:
#     Transp_Mesh  PTFE_ref     LCE    LY    LY0
# 0      0.897705      0.95  0.2980  3.56   5.99
# 1      0.897705      0.99  0.3297  3.94   6.63
# 2      0.930000      0.95  0.3344  3.97   6.70
# 3      0.930000      0.99  0.3719  4.42   7.45
# 4      0.999000      0.95  0.4508  5.31   8.94
# 5      0.999000      0.99  0.5175  6.09  10.27
# 6      0.800000      0.95  0.2209  2.67   4.49
# 7      0.800000      0.99  0.2402  2.90   4.89
# 8      0.970000      0.95  0.3929  4.64   7.83
# 9      0.970000      0.99  0.4432  5.24   8.83
# 10     0.850000      0.95  0.2550  3.06   5.16
# 11     0.850000      0.99  0.2803  3.37   5.67

# %%
#############################################
## Set plot styles:
#############################################

fig=plt.figure(figsize=(16, 10), dpi=150)

# Text options
plt.rc('text', usetex=True)
plt.rc('font', family='serif')

# Labels
label_size = 32.5 #25
label_pad = 13 #10
title_size = 39 #30
title_pad = 26 #20

# Axes Parameters
axes = plt.gca()
axes.tick_params(axis='both') 

# Axes ---> Linewidth
for axis in ['top','bottom','left','right']:
    axes.spines[axis].set_linewidth(2.2)
    
# Axes ---> Ticks
axes.xaxis.set_minor_locator(AutoMinorLocator(5)) 
plt.tick_params(which='minor', direction='in', labelsize=label_size, top=True, right=True, width=1.2, length=6)
axes.yaxis.set_minor_locator(AutoMinorLocator(5))
plt.tick_params(which='minor', direction='in', labelsize=label_size, top=True, right=True, width=1.2, length=6)
plt.tick_params(which='major', direction='in', labelsize=label_size, top=True, right=True, width=1.2, length=12)

# Grid
plt.grid(True)
    
#############################################
## Plot specific settings and plot data
#############################################

# Data plot
x = opticals["Transp_Mesh"][opticals["PTFE_ref"] == 0.99]
y = opticals["LCE"][opticals["PTFE_ref"] == 0.99]
plt.scatter(x,y, label = "99 $\%$", color = "red", s = 80)

x = opticals["Transp_Mesh"][opticals["PTFE_ref"] == 0.95]
y = opticals["LCE"][opticals["PTFE_ref"] == 0.95]
plt.scatter(x,y, label = "95 $\%$", color = "blue", s = 80)

plt.xlabel('Transparency Electrode Meshes', fontsize = label_size, labelpad = label_pad)
plt.ylabel('Average LCE', fontsize = label_size, labelpad = label_pad)
plt.title('Influence of the Electrode Mesh Transparency on the LCE', fontsize = title_size, pad = title_pad)

#plt.axvline(0.89770509, alpha=0.9, color='dimgrey', linestyle = 'dashed')

# Legend
leg = plt.legend(loc=4, bbox_to_anchor=(0.99,0.01), title="PTFE Reflectivity", fontsize=0.9*label_size, frameon=True, shadow=False, edgecolor='black', fancybox=False)
leg.get_title().set_fontsize(0.9*label_size)
for line in leg.get_lines(): # enumerated
    line.set_linewidth(4)
leg.get_frame().set_linewidth(2.5)
leg._legend_box.align = "left"

# Axes ---> Range
#plt.xlim(-20,520)
#plt.ylim(0,0.4)
#plt.ylim(bottom=0)
#plt.xlim(left=0)
#plt.gca().set_xscale('log')

fig.savefig("Influence_TranspMeshes_LCE.png")
plt.show()

# %%
#############################################
## Set plot styles:
#############################################

fig=plt.figure(figsize=(16, 10), dpi=150)

# Text options
plt.rc('text', usetex=True)
plt.rc('font', family='serif')

# Labels
label_size = 32.5 #25
label_pad = 13 #10
title_size = 39 #30
title_pad = 26 #20

# Axes Parameters
axes = plt.gca()
axes.tick_params(axis='both') 

# Axes ---> Linewidth
for axis in ['top','bottom','left','right']:
    axes.spines[axis].set_linewidth(2.2)
    
# Axes ---> Ticks
axes.xaxis.set_minor_locator(AutoMinorLocator(5)) 
plt.tick_params(which='minor', direction='in', labelsize=label_size, top=True, right=True, width=1.2, length=6)
axes.yaxis.set_minor_locator(AutoMinorLocator(5))
plt.tick_params(which='minor', direction='in', labelsize=label_size, top=True, right=True, width=1.2, length=6)
plt.tick_params(which='major', direction='in', labelsize=label_size, top=True, right=True, width=1.2, length=12)

# Grid
plt.grid(True)
    
#############################################
## Plot specific settings and plot data
#############################################

# Data plot
x = opticals["Transp_Mesh"][opticals["PTFE_ref"] == 0.99]
y = opticals["LY"][opticals["PTFE_ref"] == 0.99]
plt.scatter(x,y, label = "99 $\%$", color = "red", s = 80)

x = opticals["Transp_Mesh"][opticals["PTFE_ref"] == 0.95]
y = opticals["LY"][opticals["PTFE_ref"] == 0.95]
plt.scatter(x,y, label = "95 $\%$", color = "blue", s = 80)

plt.xlabel('Transparency Electrode Meshes', fontsize = label_size, labelpad = label_pad)
plt.ylabel('Average LY [pe/keV] for 1/W = '+str(round(1/W,2))+' ph/keV', fontsize = label_size, labelpad = label_pad)
plt.title('Influence of the Electrode Mesh Transparency on the LY', fontsize = title_size, pad = title_pad)

#plt.axvline(0.89770509, alpha=0.9, color='dimgrey', linestyle = 'dashed')

# Legend
leg = plt.legend(loc=4, bbox_to_anchor=(0.99,0.01), title="PTFE Reflectivity", fontsize=0.9*label_size, frameon=True, shadow=False, edgecolor='black', fancybox=False)
leg.get_title().set_fontsize(0.9*label_size)
for line in leg.get_lines(): # enumerated
    line.set_linewidth(4)
leg.get_frame().set_linewidth(2.5)
leg._legend_box.align = "left"

# Axes ---> Range
#plt.xlim(-20,520)
#plt.ylim(0,0.4)
#plt.ylim(bottom=0)
#plt.xlim(left=0)
#plt.gca().set_xscale('log')

fig.savefig("Influence_TranspMeshes_LY.png")
plt.show()

# %%
#############################################
## Set plot styles:
#############################################

fig=plt.figure(figsize=(16, 10), dpi=150)

# Text options
plt.rc('text', usetex=True)
plt.rc('font', family='serif')

# Labels
label_size = 32.5 #25
label_pad = 13 #10
title_size = 39 #30
title_pad = 26 #20

# Axes Parameters
axes = plt.gca()
axes.tick_params(axis='both') 

# Axes ---> Linewidth
for axis in ['top','bottom','left','right']:
    axes.spines[axis].set_linewidth(2.2)
    
# Axes ---> Ticks
axes.xaxis.set_minor_locator(AutoMinorLocator(5)) 
plt.tick_params(which='minor', direction='in', labelsize=label_size, top=True, right=True, width=1.2, length=6)
axes.yaxis.set_minor_locator(AutoMinorLocator(5))
plt.tick_params(which='minor', direction='in', labelsize=label_size, top=True, right=True, width=1.2, length=6)
plt.tick_params(which='major', direction='in', labelsize=label_size, top=True, right=True, width=1.2, length=12)

# Grid
plt.grid(True)
    
#############################################
## Plot specific settings and plot data
#############################################

# Data plot
x = opticals["Transp_Mesh"][opticals["PTFE_ref"] == 0.99]
y = opticals["LY0"][opticals["PTFE_ref"] == 0.99]
plt.scatter(x,y, label = "99 $\%$", color = "red", s = 80)

x = opticals["Transp_Mesh"][opticals["PTFE_ref"] == 0.95]
y = opticals["LY0"][opticals["PTFE_ref"] == 0.95]
plt.scatter(x,y, label = "95 $\%$", color = "blue", s = 80)

plt.xlabel('Transparency Electrode Meshes', fontsize = label_size, labelpad = label_pad)
plt.ylabel('Average LY [pe/keV] for 1/W = '+str(round(1/W0,2))+' ph/keV', fontsize = label_size, labelpad = label_pad)
plt.title('Influence of the Electrode Mesh Transparency on the LY', fontsize = title_size, pad = title_pad)

#plt.axvline(0.89770509, alpha=0.9, color='dimgrey', linestyle = 'dashed')

# Legend
leg = plt.legend(loc=4, bbox_to_anchor=(0.99,0.01), title="PTFE Reflectivity", fontsize=0.9*label_size, frameon=True, shadow=False, edgecolor='black', fancybox=False)
leg.get_title().set_fontsize(0.9*label_size)
for line in leg.get_lines(): # enumerated
    line.set_linewidth(4)
leg.get_frame().set_linewidth(2.5)
leg._legend_box.align = "left"

# Axes ---> Range
#plt.xlim(-20,520)
#plt.ylim(0,0.4)
#plt.ylim(bottom=0)
#plt.xlim(left=0)
#plt.gca().set_xscale('log')

fig.savefig("Influence_TranspMeshes_LY0.png")
plt.show()
