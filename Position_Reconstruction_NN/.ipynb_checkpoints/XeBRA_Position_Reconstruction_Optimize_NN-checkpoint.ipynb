# %% [markdown]
# # Position Reconstruction for XeBRA - Neural Networks
#
# **Status:** August 2019
#
# Position reconstruction for XeBRA using a feedforward neural network with Keras.
# Purpose of this notebook: Keras Hyperparameter Tuning using Hyperas.

# %%
#############################################
## Use Google Colab:
#############################################
b_GC = False # True or False, also adjust in data()!

if b_GC == True:
    # !pip install hyperas
    # !pip install hyperopt
    # !pip install uproot
    # !pip install numpy
    # !pip install pandas

# %%
#############################################
## Imports:
#############################################

from __future__ import print_function
import numpy as np

from hyperopt import Trials, STATUS_OK, tpe
from keras.layers.core import Dense, Dropout, Activation
from keras.models import Sequential
from keras.utils import np_utils
from keras.optimizers import SGD,Adam

from hyperas import optim
from hyperas.distributions import choice, uniform

import os
import glob
import uproot
import pandas as pd
# Out:
# Using TensorFlow backend.

# %%
if b_GC == True:
    ## Import datasets uploaded on Google Drive
    ## by mounting the Google Drive into the runtime.
    from google.colab import drive
    drive.mount('/content/gdrive')
    # !ls 'gdrive/My Drive/Colab Notebooks'

# %%
#############################################
## Preparing the Data
#############################################

def data():
    """
    Data providing function:

    This function is separated from create_model() so that hyperopt
    won't reload data for each evaluation run.
    """

    ## Selection of file(s) to be used:
    b_GC = False # True or False
    if b_GC == True:
        filename_list = glob.glob("gdrive/My Drive/Simulation Data/optPhot_S2_1.0e+05_pmtGap4.5_RPTFE0.95_LXeAbs100_Tmesh0.89770509_writeEmptyFalse_nop_1.0e+04_*.root")
    else:
        filename_list = glob.glob("/media/ab602/TOSHIBA EXT/Simulation_Data/LCE/optPhot_S2_1.0e+05_pmtGap4.5_RPTFE0.95_LXeAbs100_Tmesh0.89770509_writeEmptyFalse_nop_1.0e+04_*.root")                
    file_split_train = 0.9 # fraction of file used for training
    
    ## Import as pandas dataframes
    branches= ['xp_pri','yp_pri','zp_pri','ntpmthits','pmthits'] # Be careful that the branches are also initilized in _chunk_collect
    import concurrent.futures
    executor = concurrent.futures.ThreadPoolExecutor(8)
    _chunk_collect = pd.DataFrame({'xp_pri' : [],'yp_pri' : [],'zp_pri' : [], 'ntpmthits' : [],'pmthits' : []}) # Initialize empty data frame
    for _chunk in uproot.iterate(filename_list, "events/events",branches, entrysteps=100000, 
                                           outputtype=pd.DataFrame, executor=executor):
        _chunk.columns=branches
        _chunk_collect=_chunk_collect.append(_chunk)

    ## Normalize to hits fractions
    _chunk_collect['pmthits'] = (_chunk_collect['pmthits'] / _chunk_collect['ntpmthits'])

    ## Separate hits for individual PMTs
    ## Takes a while to calculate...
    for i in range(1,8):
        _chunk_collect['pmthits_'+str(i)] = pd.Series([tupl[i] for tupl in np.asarray(_chunk_collect['pmthits'])], index=_chunk_collect.index)

    _chunk_collect = _chunk_collect.drop(columns=['pmthits'])
    _chunk_collect = _chunk_collect.drop(columns=['ntpmthits'])

    ## Separate labels and features
    features=['pmthits_1','pmthits_7']
    labels=['xp_pri','yp_pri']

    ## Split arrays into (random) train and test subsets.
    ## Could also be done with sklearn.model_selection.train_test_split,
    ## but already randomized from simulation (see plots bleow).
    train_label     = _chunk_collect.loc[:int(np.floor(_chunk_collect.shape[0]*file_split_train))-1,labels]
    predict_label   = _chunk_collect.loc[int(np.floor(_chunk_collect.shape[0]*file_split_train)):,labels]
    train_feature   = _chunk_collect.loc[:int(np.floor(_chunk_collect.shape[0]*file_split_train))-1,features[0]:features[1]]
    predict_feature = _chunk_collect.loc[int(np.floor(_chunk_collect.shape[0]*file_split_train)):,features[0]:features[1]]

    del(_chunk_collect)

    ## Convert to numpy arrays
    train_feature   = train_feature.to_numpy()
    train_label     = train_label.to_numpy()
    predict_feature = predict_feature.to_numpy()
    predict_label   = predict_label.to_numpy()

    ## Normalize labels to [-0.5, 0.5] to make network easier to train 
    ## as using smaller, centered values is often better.
    ## Have to rescale later.
    scaling_factor = 70
    train_label = train_label/scaling_factor
    predict_label = predict_label/scaling_factor
    
    ## Return
    return train_feature, train_label, predict_feature, predict_label

# %%
#############################################
## Function for optimizing the NN
#############################################

def create_model(train_feature, train_label, predict_feature, predict_label):
    """
    Model providing function:

    Create Keras model with double curly brackets dropped-in as needed.
    Return value has to be a valid python dictionary with two customary keys:
        - loss: Specify a numeric evaluation metric to be minimized
        - status: Just use STATUS_OK and see hyperopt documentation if not feasible
    The last one is optional, though recommended, namely:
        - model: specify the model just created so that we can later use it again.
    """
    
    ## Building the Model
    pmts = int(7) # number of PMTs
    
    model = Sequential()
    model.add(Dense(64, input_shape=(pmts,)))
    model.add(Activation('relu'))
    model.add(Dense(64))
    model.add(Activation('relu'))
    model.add(Dense(2))  # x and y
    model.add(Activation('linear'))
    
    ## Compiling the Model
    model.compile(optimizer=Adam(lr={{choice([0.0001, 0.0002, 0.0003, 0.0005, 0.001, 0.002, 0.003, 0.005, 0.01, 0.02, 0.03, 0.05, 0.1, 0.2, 0.3, 0.5])}}),
                  loss='mean_squared_error',
                  metrics=['mean_squared_error']
             )
    
    ## Training the Model
    result = model.fit(train_feature, train_label,
                       epochs=100,
                       batch_size=128,
                       validation_split=0.3,
                       verbose=2
                      )
    
    ## Get the lowest validation loss of the training epochs
    validation_loss = np.amin(result.history['val_loss']) 
    print('Best validation loss of epoch:', validation_loss)
    return {'loss': validation_loss, 'status': STATUS_OK, 'model': model}

# %%
#############################################
## Optimize the NN
## Make max_evals sufficiently large to cover
## entire paramater space.
#############################################

max_ev = 20

if b_GC == True:
    best_run, best_model = optim.minimize(model=create_model,
                                          data=data,
                                          algo=tpe.suggest,
                                          max_evals=max_ev,
                                          trials=Trials(),
                                          eval_space = True,
                                          notebook_name='gdrive/My Drive/Colab Notebooks/XeBRA_Position_Reconstruction_Optimize_NN',
                                          keep_temp=False
                                         )
else: 
    best_run, best_model = optim.minimize(model=create_model,
                                          data=data,
                                          algo=tpe.suggest,
                                          max_evals=max_ev,
                                          trials=Trials(),
                                          eval_space = True,
                                          notebook_name='XeBRA_Position_Reconstruction_Optimize_NN',
                                          keep_temp=False
                                         )
# Out:
# >>> Imports:
# #coding=utf-8
#
# from __future__ import print_function
#
# try:
#     import numpy as np
# except:
#     pass
#
# try:
#     from hyperopt import Trials, STATUS_OK, tpe
# except:
#     pass
#
# try:
#     from keras.layers.core import Dense, Dropout, Activation
# except:
#     pass
#
# try:
#     from keras.models import Sequential
# except:
#     pass
#
# try:
#     from keras.utils import np_utils
# except:
#     pass
#
# try:
#     from keras.optimizers import SGD, Adam
# except:
#     pass
#
# try:
#     from hyperas import optim
# except:
#     pass
#
# try:
#     from hyperas.distributions import choice, uniform
# except:
#     pass
#
# try:
#     import os
# except:
#     pass
#
# try:
#     import glob
# except:
#     pass
#
# try:
#     import uproot
# except:
#     pass
#
# try:
#     import pandas as pd
# except:
#     pass
#
# try:
#     from google.colab import drive
# except:
#     pass
#
# try:
#     import concurrent.futures
# except:
#     pass
#
# >>> Hyperas search space:
#
# def get_space():
#     return {
#         'lr': hp.choice('lr', [0.0001, 0.0002, 0.0003, 0.0005, 0.001, 0.002, 0.003, 0.005, 0.01, 0.02, 0.03, 0.05, 0.1, 0.2, 0.3, 0.5]),
#     }
#
# >>> Data
#    1:
#    2: """
#    3: Data providing function:
#    4:
#    5: This function is separated from create_model() so that hyperopt
#    6: won't reload data for each evaluation run.
#    7: """
#    8:
#    9: ## Selection of file(s) to be used:
#   10: b_GC = False # True or False
#   11: if b_GC == True:
#   12:     filename_list = glob.glob("gdrive/My Drive/Simulation Data/optPhot_S2_1.0e+05_pmtGap4.5_RPTFE0.95_LXeAbs100_Tmesh0.89770509_writeEmptyFalse_nop_1.0e+04_*.root")
#   13: else:
#   14:     filename_list = glob.glob("/media/ab602/TOSHIBA EXT/Simulation_Data/LCE/optPhot_S2_1.0e+05_pmtGap4.5_RPTFE0.95_LXeAbs100_Tmesh0.89770509_writeEmptyFalse_nop_1.0e+04_*.root")
#   15: file_split_train = 0.9 # fraction of file used for training
#   16:
#   17: ## Import as pandas dataframes
#   18: branches= ['xp_pri','yp_pri','zp_pri','ntpmthits','pmthits'] # Be careful that the branches are also initilized in _chunk_collect
#   19: import concurrent.futures
#   20: executor = concurrent.futures.ThreadPoolExecutor(8)
#   21: _chunk_collect = pd.DataFrame({'xp_pri' : [],'yp_pri' : [],'zp_pri' : [], 'ntpmthits' : [],'pmthits' : []}) # Initialize empty data frame
#   22: for _chunk in uproot.iterate(filename_list, "events/events",branches, entrysteps=100000,
#   23:                                        outputtype=pd.DataFrame, executor=executor):
#   24:     _chunk.columns=branches
#   25:     _chunk_collect=_chunk_collect.append(_chunk)
#   26:
#   27: ## Normalize to hits fractions
#   28: _chunk_collect['pmthits'] = (_chunk_collect['pmthits'] / _chunk_collect['ntpmthits'])
#   29:
#   30: ## Separate hits for individual PMTs
#   31: ## Takes a while to calculate...
#   32: for i in range(1,8):
#   33:     _chunk_collect['pmthits_'+str(i)] = pd.Series([tupl[i] for tupl in np.asarray(_chunk_collect['pmthits'])], index=_chunk_collect.index)
#   34:
#   35: _chunk_collect = _chunk_collect.drop(columns=['pmthits'])
#   36: _chunk_collect = _chunk_collect.drop(columns=['ntpmthits'])
#   37:
#   38: ## Separate labels and features
#   39: features=['pmthits_1','pmthits_7']
#   40: labels=['xp_pri','yp_pri']
#   41:
#   42: ## Split arrays into (random) train and test subsets.
#   43: ## Could also be done with sklearn.model_selection.train_test_split,
#   44: ## but already randomized from simulation (see plots bleow).
#   45: train_label     = _chunk_collect.loc[:int(np.floor(_chunk_collect.shape[0]*file_split_train))-1,labels]
#   46: predict_label   = _chunk_collect.loc[int(np.floor(_chunk_collect.shape[0]*file_split_train)):,labels]
#   47: train_feature   = _chunk_collect.loc[:int(np.floor(_chunk_collect.shape[0]*file_split_train))-1,features[0]:features[1]]
#   48: predict_feature = _chunk_collect.loc[int(np.floor(_chunk_collect.shape[0]*file_split_train)):,features[0]:features[1]]
#   49:
#   50: del(_chunk_collect)
#   51:
#   52: ## Convert to numpy arrays
#   53: train_feature   = train_feature.to_numpy()
#   54: train_label     = train_label.to_numpy()
#   55: predict_feature = predict_feature.to_numpy()
#   56: predict_label   = predict_label.to_numpy()
#   57:
#   58: ## Normalize labels to [-0.5, 0.5] to make network easier to train
#   59: ## as using smaller, centered values is often better.
#   60: ## Have to rescale later.
#   61: scaling_factor = 70
#   62: train_label = train_label/scaling_factor
#   63: predict_label = predict_label/scaling_factor
#   64:
#   65: ## Return
#   66:
#   67:
#   68:
# >>> Resulting replaced keras model:
#
#    1: def keras_fmin_fnct(space):
#    2:
#    3:     """
#    4:     Model providing function:
#    5:
#    6:     Create Keras model with double curly brackets dropped-in as needed.
#    7:     Return value has to be a valid python dictionary with two customary keys:
#    8:         - loss: Specify a numeric evaluation metric to be minimized
#    9:         - status: Just use STATUS_OK and see hyperopt documentation if not feasible
#   10:     The last one is optional, though recommended, namely:
#   11:         - model: specify the model just created so that we can later use it again.
#   12:     """
#   13:
#   14:     ## Building the Model
#   15:     pmts = int(7) # number of PMTs
#   16:
#   17:     model = Sequential()
#   18:     model.add(Dense(64, input_shape=(pmts,)))
#   19:     model.add(Activation('relu'))
#   20:     model.add(Dense(64))
#   21:     model.add(Activation('relu'))
#   22:     model.add(Dense(2))  # x and y
#   23:     model.add(Activation('linear'))
#   24:
#   25:     ## Compiling the Model
#   26:     model.compile(optimizer=Adam(lr=space['lr']),
#   27:                   loss='mean_squared_error',
#   28:                   metrics=['mean_squared_error']
#   29:              )
#   30:
#   31:     ## Training the Model
#   32:     result = model.fit(train_feature, train_label,
#   33:                        epochs=100,
#   34:                        batch_size=128,
#   35:                        validation_split=0.3,
#   36:                        verbose=2
#   37:                       )
#   38:
#   39:     ## Get the lowest validation loss of the training epochs
#   40:     validation_loss = np.amin(result.history['val_loss'])
#   41:     print('Best validation loss of epoch:', validation_loss)
#   42:     return {'loss': validation_loss, 'status': STATUS_OK, 'model': model}
#   43:
# /home/ab602/anaconda3/lib/python3.7/site-packages/uproot/tree.py:116: FutureWarning: Int64Index.data is deprecated and will be removed in a future version
#   index = awkward.numpy.frombuffer(arrays.index.data, dtype=arrays.index.dtype)
#   0%|          | 0/20 [00:00<?, ?it/s, best loss: ?]
# WARNING: Logging before flag parsing goes to stderr.
#
# W0823 11:08:09.777330 139847701288768 deprecation_wrapper.py:119] From /home/ab602/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
#
# W0823 11:08:09.788639 139847701288768 deprecation_wrapper.py:119] From /home/ab602/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
#
# W0823 11:08:09.791442 139847701288768 deprecation_wrapper.py:119] From /home/ab602/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
#
# W0823 11:08:09.828700 139847701288768 deprecation_wrapper.py:119] From /home/ab602/anaconda3/lib/python3.7/site-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
#
# W0823 11:08:09.905021 139847701288768 deprecation_wrapper.py:119] From /home/ab602/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
#
# W0823 11:08:09.961745 139847701288768 deprecation_wrapper.py:119] From /home/ab602/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:973: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
# Train on 630000 samples, validate on 270000 samples
# Epoch 1/100
#  - 6s - loss: 6.3319e-04 - mean_squared_error: 6.3319e-04 - val_loss: 4.6687e-04 - val_mean_squared_error: 4.6687e-04
#
# Epoch 2/100
#  - 7s - loss: 4.3453e-04 - mean_squared_error: 4.3453e-04 - val_loss: 4.3416e-04 - val_mean_squared_error: 4.3416e-04
#
# Epoch 3/100
#  - 7s - loss: 4.2053e-04 - mean_squared_error: 4.2053e-04 - val_loss: 4.3973e-04 - val_mean_squared_error: 4.3973e-04
#
# Epoch 4/100
#  - 9s - loss: 4.1333e-04 - mean_squared_error: 4.1333e-04 - val_loss: 4.0120e-04 - val_mean_squared_error: 4.0120e-04
#
# Epoch 5/100
#  - 9s - loss: 4.0739e-04 - mean_squared_error: 4.0739e-04 - val_loss: 3.8410e-04 - val_mean_squared_error: 3.8410e-04
#
# Epoch 6/100
#  - 8s - loss: 4.0626e-04 - mean_squared_error: 4.0626e-04 - val_loss: 4.1216e-04 - val_mean_squared_error: 4.1216e-04
#
# Epoch 7/100
#  - 9s - loss: 4.0277e-04 - mean_squared_error: 4.0277e-04 - val_loss: 4.2037e-04 - val_mean_squared_error: 4.2037e-04
#
# Epoch 8/100
#  - 8s - loss: 4.0127e-04 - mean_squared_error: 4.0127e-04 - val_loss: 4.1715e-04 - val_mean_squared_error: 4.1715e-04
#
# Epoch 9/100
#  - 7s - loss: 3.9961e-04 - mean_squared_error: 3.9961e-04 - val_loss: 3.9275e-04 - val_mean_squared_error: 3.9275e-04
#
# Epoch 10/100
#  - 8s - loss: 3.9813e-04 - mean_squared_error: 3.9813e-04 - val_loss: 4.0873e-04 - val_mean_squared_error: 4.0873e-04
#
# Epoch 11/100
#  - 6s - loss: 3.9696e-04 - mean_squared_error: 3.9696e-04 - val_loss: 3.8920e-04 - val_mean_squared_error: 3.8920e-04
#
# Epoch 12/100
#  - 7s - loss: 3.9638e-04 - mean_squared_error: 3.9638e-04 - val_loss: 3.8248e-04 - val_mean_squared_error: 3.8248e-04
#
# Epoch 13/100
#  - 11s - loss: 3.9655e-04 - mean_squared_error: 3.9655e-04 - val_loss: 3.9776e-04 - val_mean_squared_error: 3.9776e-04
#
# Epoch 14/100
#  - 9s - loss: 3.9517e-04 - mean_squared_error: 3.9517e-04 - val_loss: 4.0090e-04 - val_mean_squared_error: 4.0090e-04
#
# Epoch 15/100
#  - 6s - loss: 3.9429e-04 - mean_squared_error: 3.9429e-04 - val_loss: 3.8008e-04 - val_mean_squared_error: 3.8008e-04
#
# Epoch 16/100
#  - 6s - loss: 3.9343e-04 - mean_squared_error: 3.9343e-04 - val_loss: 3.8531e-04 - val_mean_squared_error: 3.8531e-04
#
# Epoch 17/100
#  - 7s - loss: 3.9330e-04 - mean_squared_error: 3.9330e-04 - val_loss: 3.8366e-04 - val_mean_squared_error: 3.8366e-04
#
# Epoch 18/100
#  - 8s - loss: 3.9277e-04 - mean_squared_error: 3.9277e-04 - val_loss: 4.1167e-04 - val_mean_squared_error: 4.1167e-04
#
# Epoch 19/100
#  - 7s - loss: 3.9363e-04 - mean_squared_error: 3.9363e-04 - val_loss: 3.9273e-04 - val_mean_squared_error: 3.9273e-04
#
# Epoch 20/100
#  - 8s - loss: 3.9303e-04 - mean_squared_error: 3.9303e-04 - val_loss: 3.9634e-04 - val_mean_squared_error: 3.9634e-04
#
# Epoch 21/100
#  - 9s - loss: 3.9285e-04 - mean_squared_error: 3.9285e-04 - val_loss: 3.8163e-04 - val_mean_squared_error: 3.8163e-04
#
# Epoch 22/100
#  - 5s - loss: 3.9214e-04 - mean_squared_error: 3.9214e-04 - val_loss: 3.9107e-04 - val_mean_squared_error: 3.9107e-04
#
# Epoch 23/100
#  - 8s - loss: 3.9208e-04 - mean_squared_error: 3.9208e-04 - val_loss: 4.1232e-04 - val_mean_squared_error: 4.1232e-04
#
# Epoch 24/100
#  - 8s - loss: 3.9198e-04 - mean_squared_error: 3.9198e-04 - val_loss: 3.9895e-04 - val_mean_squared_error: 3.9895e-04
#
# Epoch 25/100
#  - 9s - loss: 3.9089e-04 - mean_squared_error: 3.9089e-04 - val_loss: 3.8178e-04 - val_mean_squared_error: 3.8178e-04
#
# Epoch 26/100
#  - 7s - loss: 3.9108e-04 - mean_squared_error: 3.9108e-04 - val_loss: 3.8472e-04 - val_mean_squared_error: 3.8472e-04
#
# Epoch 27/100
#  - 10s - loss: 3.9100e-04 - mean_squared_error: 3.9100e-04 - val_loss: 4.2376e-04 - val_mean_squared_error: 4.2376e-04
#
# Epoch 28/100
#  - 8s - loss: 3.9081e-04 - mean_squared_error: 3.9081e-04 - val_loss: 3.8661e-04 - val_mean_squared_error: 3.8661e-04
#
# Epoch 29/100
#  - 9s - loss: 3.9072e-04 - mean_squared_error: 3.9072e-04 - val_loss: 3.9310e-04 - val_mean_squared_error: 3.9310e-04
#
# Epoch 30/100
#  - 9s - loss: 3.9104e-04 - mean_squared_error: 3.9104e-04 - val_loss: 3.8052e-04 - val_mean_squared_error: 3.8052e-04
#
# Epoch 31/100
#  - 9s - loss: 3.9061e-04 - mean_squared_error: 3.9061e-04 - val_loss: 3.8376e-04 - val_mean_squared_error: 3.8376e-04
#
# Epoch 32/100
#  - 7s - loss: 3.9055e-04 - mean_squared_error: 3.9055e-04 - val_loss: 3.9005e-04 - val_mean_squared_error: 3.9005e-04
#
# Epoch 33/100
#  - 8s - loss: 3.9017e-04 - mean_squared_error: 3.9017e-04 - val_loss: 3.8870e-04 - val_mean_squared_error: 3.8870e-04
#
# Epoch 34/100
#  - 9s - loss: 3.9017e-04 - mean_squared_error: 3.9017e-04 - val_loss: 4.0699e-04 - val_mean_squared_error: 4.0699e-04
#
# Epoch 35/100
#  - 11s - loss: 3.8980e-04 - mean_squared_error: 3.8980e-04 - val_loss: 3.8129e-04 - val_mean_squared_error: 3.8129e-04
#
# Epoch 36/100
#  - 7s - loss: 3.8986e-04 - mean_squared_error: 3.8986e-04 - val_loss: 3.8559e-04 - val_mean_squared_error: 3.8559e-04
#
# Epoch 37/100
#  - 8s - loss: 3.9003e-04 - mean_squared_error: 3.9003e-04 - val_loss: 3.9792e-04 - val_mean_squared_error: 3.9792e-04
#
# Epoch 38/100
#  - 6s - loss: 3.8990e-04 - mean_squared_error: 3.8990e-04 - val_loss: 3.8308e-04 - val_mean_squared_error: 3.8308e-04
#
# Epoch 39/100
#  - 4s - loss: 3.9009e-04 - mean_squared_error: 3.9009e-04 - val_loss: 3.8969e-04 - val_mean_squared_error: 3.8969e-04
#
# Epoch 40/100
#  - 4s - loss: 3.9011e-04 - mean_squared_error: 3.9011e-04 - val_loss: 4.1013e-04 - val_mean_squared_error: 4.1013e-04
#
# Epoch 41/100
#  - 3s - loss: 3.8995e-04 - mean_squared_error: 3.8995e-04 - val_loss: 3.9416e-04 - val_mean_squared_error: 3.9416e-04
#
# Epoch 42/100
#  - 3s - loss: 3.9001e-04 - mean_squared_error: 3.9001e-04 - val_loss: 3.8313e-04 - val_mean_squared_error: 3.8313e-04
#
# Epoch 43/100
#  - 3s - loss: 3.8995e-04 - mean_squared_error: 3.8995e-04 - val_loss: 3.8086e-04 - val_mean_squared_error: 3.8086e-04
#
# Epoch 44/100
#  - 3s - loss: 3.8921e-04 - mean_squared_error: 3.8921e-04 - val_loss: 3.7963e-04 - val_mean_squared_error: 3.7963e-04
#
# Epoch 45/100
#  - 3s - loss: 3.8885e-04 - mean_squared_error: 3.8885e-04 - val_loss: 3.8229e-04 - val_mean_squared_error: 3.8229e-04
#
# Epoch 46/100
#  - 3s - loss: 3.8956e-04 - mean_squared_error: 3.8956e-04 - val_loss: 3.9025e-04 - val_mean_squared_error: 3.9025e-04
#
# Epoch 47/100
#  - 4s - loss: 3.8871e-04 - mean_squared_error: 3.8871e-04 - val_loss: 3.9328e-04 - val_mean_squared_error: 3.9328e-04
# Epoch 48/100
#  - 4s - loss: 3.8941e-04 - mean_squared_error: 3.8941e-04 - val_loss: 4.0670e-04 - val_mean_squared_error: 4.0670e-04
#
# Epoch 49/100
#  - 3s - loss: 3.8925e-04 - mean_squared_error: 3.8925e-04 - val_loss: 3.7868e-04 - val_mean_squared_error: 3.7868e-04
#
# Epoch 50/100
#  - 3s - loss: 3.8953e-04 - mean_squared_error: 3.8953e-04 - val_loss: 3.9105e-04 - val_mean_squared_error: 3.9105e-04
#
# Epoch 51/100
#  - 3s - loss: 3.8912e-04 - mean_squared_error: 3.8912e-04 - val_loss: 3.9267e-04 - val_mean_squared_error: 3.9267e-04
#
# Epoch 52/100
#  - 3s - loss: 3.8941e-04 - mean_squared_error: 3.8941e-04 - val_loss: 3.9307e-04 - val_mean_squared_error: 3.9307e-04
#
# Epoch 53/100
#  - 3s - loss: 3.8964e-04 - mean_squared_error: 3.8964e-04 - val_loss: 3.9979e-04 - val_mean_squared_error: 3.9979e-04
#
# Epoch 54/100
#  - 3s - loss: 3.8842e-04 - mean_squared_error: 3.8842e-04 - val_loss: 4.0703e-04 - val_mean_squared_error: 4.0703e-04
#
# Epoch 55/100
#  - 3s - loss: 3.8892e-04 - mean_squared_error: 3.8892e-04 - val_loss: 3.9758e-04 - val_mean_squared_error: 3.9758e-04
#
# Epoch 56/100
#  - 5s - loss: 3.8909e-04 - mean_squared_error: 3.8909e-04 - val_loss: 3.8941e-04 - val_mean_squared_error: 3.8941e-04
#
# Epoch 57/100
#  - 9s - loss: 3.8886e-04 - mean_squared_error: 3.8886e-04 - val_loss: 3.7955e-04 - val_mean_squared_error: 3.7955e-04
#
# Epoch 58/100
#  - 11s - loss: 3.8857e-04 - mean_squared_error: 3.8857e-04 - val_loss: 3.8916e-04 - val_mean_squared_error: 3.8916e-04
#
# Epoch 59/100
#  - 6s - loss: 3.8890e-04 - mean_squared_error: 3.8890e-04 - val_loss: 3.8192e-04 - val_mean_squared_error: 3.8192e-04
#
# Epoch 60/100
#  - 10s - loss: 3.8890e-04 - mean_squared_error: 3.8890e-04 - val_loss: 3.9564e-04 - val_mean_squared_error: 3.9564e-04
#
# Epoch 61/100
#  - 9s - loss: 3.8893e-04 - mean_squared_error: 3.8893e-04 - val_loss: 3.8808e-04 - val_mean_squared_error: 3.8808e-04
#
# Epoch 62/100
#  - 7s - loss: 3.8952e-04 - mean_squared_error: 3.8952e-04 - val_loss: 3.8790e-04 - val_mean_squared_error: 3.8790e-04
#
# Epoch 63/100
#  - 6s - loss: 3.8848e-04 - mean_squared_error: 3.8848e-04 - val_loss: 3.9191e-04 - val_mean_squared_error: 3.9191e-04
#
# Epoch 64/100
#  - 9s - loss: 3.8867e-04 - mean_squared_error: 3.8867e-04 - val_loss: 3.8374e-04 - val_mean_squared_error: 3.8374e-04
#
# Epoch 65/100
#  - 9s - loss: 3.8892e-04 - mean_squared_error: 3.8892e-04 - val_loss: 3.9073e-04 - val_mean_squared_error: 3.9073e-04
#
# Epoch 66/100
#  - 8s - loss: 3.8914e-04 - mean_squared_error: 3.8914e-04 - val_loss: 3.9386e-04 - val_mean_squared_error: 3.9386e-04
#
# Epoch 67/100
#  - 11s - loss: 3.8864e-04 - mean_squared_error: 3.8864e-04 - val_loss: 3.8211e-04 - val_mean_squared_error: 3.8211e-04
#
# Epoch 68/100
#  - 12s - loss: 3.8893e-04 - mean_squared_error: 3.8893e-04 - val_loss: 3.7745e-04 - val_mean_squared_error: 3.7745e-04
#
# Epoch 69/100
#  - 9s - loss: 3.8901e-04 - mean_squared_error: 3.8901e-04 - val_loss: 3.8441e-04 - val_mean_squared_error: 3.8441e-04
#
# Epoch 70/100
#  - 10s - loss: 3.8895e-04 - mean_squared_error: 3.8895e-04 - val_loss: 3.8884e-04 - val_mean_squared_error: 3.8884e-04
#
# Epoch 71/100
#  - 8s - loss: 3.8820e-04 - mean_squared_error: 3.8820e-04 - val_loss: 3.8125e-04 - val_mean_squared_error: 3.8125e-04
#
# Epoch 72/100
#  - 10s - loss: 3.8872e-04 - mean_squared_error: 3.8872e-04 - val_loss: 3.9920e-04 - val_mean_squared_error: 3.9920e-04
#
# Epoch 73/100
#  - 10s - loss: 3.8966e-04 - mean_squared_error: 3.8966e-04 - val_loss: 3.9024e-04 - val_mean_squared_error: 3.9024e-04
#
# Epoch 74/100
#  - 11s - loss: 3.8902e-04 - mean_squared_error: 3.8902e-04 - val_loss: 3.7874e-04 - val_mean_squared_error: 3.7874e-04
#
# Epoch 75/100
#  - 9s - loss: 3.8946e-04 - mean_squared_error: 3.8946e-04 - val_loss: 3.8156e-04 - val_mean_squared_error: 3.8156e-04
#
# Epoch 76/100
#  - 10s - loss: 3.8863e-04 - mean_squared_error: 3.8863e-04 - val_loss: 3.8983e-04 - val_mean_squared_error: 3.8983e-04
#
# Epoch 77/100
#  - 8s - loss: 3.8853e-04 - mean_squared_error: 3.8853e-04 - val_loss: 3.9112e-04 - val_mean_squared_error: 3.9112e-04
#
# Epoch 78/100
#  - 9s - loss: 3.8916e-04 - mean_squared_error: 3.8916e-04 - val_loss: 3.8716e-04 - val_mean_squared_error: 3.8716e-04
#
# Epoch 79/100
#  - 11s - loss: 3.8840e-04 - mean_squared_error: 3.8840e-04 - val_loss: 3.8779e-04 - val_mean_squared_error: 3.8779e-04
#
# Epoch 80/100
#  - 9s - loss: 3.8883e-04 - mean_squared_error: 3.8883e-04 - val_loss: 3.7995e-04 - val_mean_squared_error: 3.7995e-04
#
# Epoch 81/100
#  - 9s - loss: 3.8879e-04 - mean_squared_error: 3.8879e-04 - val_loss: 4.0355e-04 - val_mean_squared_error: 4.0355e-04
#
# Epoch 82/100
#  - 9s - loss: 3.8876e-04 - mean_squared_error: 3.8876e-04 - val_loss: 4.0262e-04 - val_mean_squared_error: 4.0262e-04
#
# Epoch 83/100
#  - 10s - loss: 3.8866e-04 - mean_squared_error: 3.8866e-04 - val_loss: 3.8144e-04 - val_mean_squared_error: 3.8144e-04
#
# Epoch 84/100
#  - 11s - loss: 3.8826e-04 - mean_squared_error: 3.8826e-04 - val_loss: 3.8310e-04 - val_mean_squared_error: 3.8310e-04
#
# Epoch 85/100
#  - 10s - loss: 3.8861e-04 - mean_squared_error: 3.8861e-04 - val_loss: 3.8966e-04 - val_mean_squared_error: 3.8966e-04
#
# Epoch 86/100
#  - 10s - loss: 3.8859e-04 - mean_squared_error: 3.8859e-04 - val_loss: 4.1305e-04 - val_mean_squared_error: 4.1305e-04
#
# Epoch 87/100
#  - 11s - loss: 3.8905e-04 - mean_squared_error: 3.8905e-04 - val_loss: 4.0748e-04 - val_mean_squared_error: 4.0748e-04
#
# Epoch 88/100
#  - 9s - loss: 3.8803e-04 - mean_squared_error: 3.8803e-04 - val_loss: 3.8230e-04 - val_mean_squared_error: 3.8230e-04
#
# Epoch 89/100
#  - 10s - loss: 3.8893e-04 - mean_squared_error: 3.8893e-04 - val_loss: 3.7581e-04 - val_mean_squared_error: 3.7581e-04
#
# Epoch 90/100
#  - 12s - loss: 3.8792e-04 - mean_squared_error: 3.8792e-04 - val_loss: 3.8092e-04 - val_mean_squared_error: 3.8092e-04
#
# Epoch 91/100
#  - 10s - loss: 3.8862e-04 - mean_squared_error: 3.8862e-04 - val_loss: 3.8962e-04 - val_mean_squared_error: 3.8962e-04
#
# Epoch 92/100
#  - 11s - loss: 3.8922e-04 - mean_squared_error: 3.8922e-04 - val_loss: 3.8353e-04 - val_mean_squared_error: 3.8353e-04
#
# Epoch 93/100
#  - 8s - loss: 3.8813e-04 - mean_squared_error: 3.8813e-04 - val_loss: 3.8118e-04 - val_mean_squared_error: 3.8118e-04
#
# Epoch 94/100
#  - 9s - loss: 3.8828e-04 - mean_squared_error: 3.8828e-04 - val_loss: 3.7752e-04 - val_mean_squared_error: 3.7752e-04
#
# Epoch 95/100
#  - 10s - loss: 3.8848e-04 - mean_squared_error: 3.8848e-04 - val_loss: 3.8553e-04 - val_mean_squared_error: 3.8553e-04
#
# Epoch 96/100
#  - 11s - loss: 3.8912e-04 - mean_squared_error: 3.8912e-04 - val_loss: 3.9981e-04 - val_mean_squared_error: 3.9981e-04
#
# Epoch 97/100
#  - 11s - loss: 3.8818e-04 - mean_squared_error: 3.8818e-04 - val_loss: 3.8481e-04 - val_mean_squared_error: 3.8481e-04
#
# Epoch 98/100
#  - 11s - loss: 3.8866e-04 - mean_squared_error: 3.8866e-04 - val_loss: 3.8931e-04 - val_mean_squared_error: 3.8931e-04
#
# Epoch 99/100
#  - 10s - loss: 3.8822e-04 - mean_squared_error: 3.8822e-04 - val_loss: 3.7983e-04 - val_mean_squared_error: 3.7983e-04
#
# Epoch 100/100
#  - 12s - loss: 3.8834e-04 - mean_squared_error: 3.8834e-04 - val_loss: 3.8253e-04 - val_mean_squared_error: 3.8253e-04
#
# Best validation loss of epoch:
# 0.00037581354100688324
# Train on 630000 samples, validate on 270000 samples
# Epoch 1/100
#  - 8s - loss: 7.5501e-04 - mean_squared_error: 7.5501e-04 - val_loss: 4.3922e-04 - val_mean_squared_error: 4.3922e-04
#
# Epoch 2/100
#  - 10s - loss: 4.2323e-04 - mean_squared_error: 4.2323e-04 - val_loss: 4.1833e-04 - val_mean_squared_error: 4.1833e-04
#
# Epoch 3/100
#  - 10s - loss: 4.0800e-04 - mean_squared_error: 4.0800e-04 - val_loss: 4.1217e-04 - val_mean_squared_error: 4.1217e-04
#
# Epoch 4/100
#  - 10s - loss: 4.0055e-04 - mean_squared_error: 4.0055e-04 - val_loss: 3.9007e-04 - val_mean_squared_error: 3.9007e-04
#
# Epoch 5/100
#  - 8s - loss: 3.9604e-04 - mean_squared_error: 3.9604e-04 - val_loss: 3.8921e-04 - val_mean_squared_error: 3.8921e-04
#
# Epoch 6/100
#  - 9s - loss: 3.9343e-04 - mean_squared_error: 3.9343e-04 - val_loss: 3.8695e-04 - val_mean_squared_error: 3.8695e-04
#
# Epoch 7/100
#  - 9s - loss: 3.9132e-04 - mean_squared_error: 3.9132e-04 - val_loss: 3.8340e-04 - val_mean_squared_error: 3.8340e-04
#
# Epoch 8/100
#  - 13s - loss: 3.8964e-04 - mean_squared_error: 3.8964e-04 - val_loss: 3.7308e-04 - val_mean_squared_error: 3.7308e-04
#
# Epoch 9/100
#  - 9s - loss: 3.8791e-04 - mean_squared_error: 3.8791e-04 - val_loss: 3.9947e-04 - val_mean_squared_error: 3.9947e-04
#
# Epoch 10/100
#  - 9s - loss: 3.8643e-04 - mean_squared_error: 3.8643e-04 - val_loss: 3.8123e-04 - val_mean_squared_error: 3.8123e-04
#
# Epoch 11/100
#  - 11s - loss: 3.8559e-04 - mean_squared_error: 3.8559e-04 - val_loss: 3.7954e-04 - val_mean_squared_error: 3.7954e-04
#
# Epoch 12/100
#  - 10s - loss: 3.8346e-04 - mean_squared_error: 3.8346e-04 - val_loss: 3.7554e-04 - val_mean_squared_error: 3.7554e-04
#
# Epoch 13/100
#  - 11s - loss: 3.8374e-04 - mean_squared_error: 3.8374e-04 - val_loss: 3.7418e-04 - val_mean_squared_error: 3.7418e-04
#
# Epoch 14/100
#  - 10s - loss: 3.8294e-04 - mean_squared_error: 3.8294e-04 - val_loss: 3.7894e-04 - val_mean_squared_error: 3.7894e-04
#
# Epoch 15/100
#  - 9s - loss: 3.8206e-04 - mean_squared_error: 3.8206e-04 - val_loss: 4.0111e-04 - val_mean_squared_error: 4.0111e-04
#
# Epoch 16/100
#  - 9s - loss: 3.8173e-04 - mean_squared_error: 3.8173e-04 - val_loss: 3.8543e-04 - val_mean_squared_error: 3.8543e-04
#
# Epoch 17/100
#  - 10s - loss: 3.8069e-04 - mean_squared_error: 3.8069e-04 - val_loss: 3.8667e-04 - val_mean_squared_error: 3.8667e-04
#
# Epoch 18/100
#  - 9s - loss: 3.7997e-04 - mean_squared_error: 3.7997e-04 - val_loss: 3.7552e-04 - val_mean_squared_error: 3.7552e-04
#
# Epoch 19/100
#  - 9s - loss: 3.8047e-04 - mean_squared_error: 3.8047e-04 - val_loss: 3.7866e-04 - val_mean_squared_error: 3.7866e-04
#
# Epoch 20/100
#  - 9s - loss: 3.7917e-04 - mean_squared_error: 3.7917e-04 - val_loss: 3.7200e-04 - val_mean_squared_error: 3.7200e-04
#
# Epoch 21/100
#  - 12s - loss: 3.7896e-04 - mean_squared_error: 3.7896e-04 - val_loss: 3.7780e-04 - val_mean_squared_error: 3.7780e-04
#
# Epoch 22/100
#  - 12s - loss: 3.7883e-04 - mean_squared_error: 3.7883e-04 - val_loss: 3.7616e-04 - val_mean_squared_error: 3.7616e-04
#
# Epoch 23/100
#  - 9s - loss: 3.7851e-04 - mean_squared_error: 3.7851e-04 - val_loss: 3.7359e-04 - val_mean_squared_error: 3.7359e-04
#
# Epoch 24/100
#  - 9s - loss: 3.7787e-04 - mean_squared_error: 3.7787e-04 - val_loss: 3.7366e-04 - val_mean_squared_error: 3.7366e-04
#
# Epoch 25/100
#  - 10s - loss: 3.7801e-04 - mean_squared_error: 3.7801e-04 - val_loss: 3.7606e-04 - val_mean_squared_error: 3.7606e-04
#
# Epoch 26/100
#  - 11s - loss: 3.7775e-04 - mean_squared_error: 3.7775e-04 - val_loss: 3.6912e-04 - val_mean_squared_error: 3.6912e-04
#
# Epoch 27/100
#  - 9s - loss: 3.7717e-04 - mean_squared_error: 3.7717e-04 - val_loss: 3.7284e-04 - val_mean_squared_error: 3.7284e-04
#
# Epoch 28/100
#  - 11s - loss: 3.7705e-04 - mean_squared_error: 3.7705e-04 - val_loss: 3.7253e-04 - val_mean_squared_error: 3.7253e-04
#
# Epoch 29/100
#  - 10s - loss: 3.7699e-04 - mean_squared_error: 3.7699e-04 - val_loss: 3.8396e-04 - val_mean_squared_error: 3.8396e-04
#
# Epoch 30/100
#  - 10s - loss: 3.7669e-04 - mean_squared_error: 3.7669e-04 - val_loss: 3.7650e-04 - val_mean_squared_error: 3.7650e-04
#
# Epoch 31/100
#  - 11s - loss: 3.7659e-04 - mean_squared_error: 3.7659e-04 - val_loss: 3.8063e-04 - val_mean_squared_error: 3.8063e-04
#
# Epoch 32/100
#  - 10s - loss: 3.7620e-04 - mean_squared_error: 3.7620e-04 - val_loss: 3.8346e-04 - val_mean_squared_error: 3.8346e-04
#
# Epoch 33/100
#  - 10s - loss: 3.7590e-04 - mean_squared_error: 3.7590e-04 - val_loss: 3.6730e-04 - val_mean_squared_error: 3.6730e-04
#
# Epoch 34/100
#  - 10s - loss: 3.7625e-04 - mean_squared_error: 3.7625e-04 - val_loss: 3.8380e-04 - val_mean_squared_error: 3.8380e-04
# Epoch 35/100
#  - 9s - loss: 3.7545e-04 - mean_squared_error: 3.7545e-04 - val_loss: 3.7451e-04 - val_mean_squared_error: 3.7451e-04
#
# Epoch 36/100
#  - 10s - loss: 3.7562e-04 - mean_squared_error: 3.7562e-04 - val_loss: 3.6970e-04 - val_mean_squared_error: 3.6970e-04
#
# Epoch 37/100
#  - 11s - loss: 3.7542e-04 - mean_squared_error: 3.7542e-04 - val_loss: 3.7713e-04 - val_mean_squared_error: 3.7713e-04
#
# Epoch 38/100
#  - 9s - loss: 3.7551e-04 - mean_squared_error: 3.7551e-04 - val_loss: 3.8261e-04 - val_mean_squared_error: 3.8261e-04
#
# Epoch 39/100
#  - 11s - loss: 3.7471e-04 - mean_squared_error: 3.7471e-04 - val_loss: 3.7609e-04 - val_mean_squared_error: 3.7609e-04
#
# Epoch 40/100
#  - 9s - loss: 3.7517e-04 - mean_squared_error: 3.7517e-04 - val_loss: 4.0016e-04 - val_mean_squared_error: 4.0016e-04
#
# Epoch 41/100
#  - 10s - loss: 3.7523e-04 - mean_squared_error: 3.7523e-04 - val_loss: 3.6557e-04 - val_mean_squared_error: 3.6557e-04
#
# Epoch 42/100
#  - 10s - loss: 3.7488e-04 - mean_squared_error: 3.7488e-04 - val_loss: 3.7777e-04 - val_mean_squared_error: 3.7777e-04
#
# Epoch 43/100
#  - 11s - loss: 3.7493e-04 - mean_squared_error: 3.7493e-04 - val_loss: 3.6662e-04 - val_mean_squared_error: 3.6662e-04
#
# Epoch 44/100
#  - 11s - loss: 3.7486e-04 - mean_squared_error: 3.7486e-04 - val_loss: 3.7896e-04 - val_mean_squared_error: 3.7896e-04
#
# Epoch 45/100
#  - 11s - loss: 3.7461e-04 - mean_squared_error: 3.7461e-04 - val_loss: 3.7072e-04 - val_mean_squared_error: 3.7072e-04
#
# Epoch 46/100
#  - 11s - loss: 3.7418e-04 - mean_squared_error: 3.7418e-04 - val_loss: 3.7083e-04 - val_mean_squared_error: 3.7083e-04
#
# Epoch 47/100
#  - 8s - loss: 3.7507e-04 - mean_squared_error: 3.7507e-04 - val_loss: 3.6963e-04 - val_mean_squared_error: 3.6963e-04
#
# Epoch 48/100
#  - 8s - loss: 3.7455e-04 - mean_squared_error: 3.7455e-04 - val_loss: 3.7740e-04 - val_mean_squared_error: 3.7740e-04
#
# Epoch 49/100
#  - 10s - loss: 3.7423e-04 - mean_squared_error: 3.7423e-04 - val_loss: 3.7921e-04 - val_mean_squared_error: 3.7921e-04
#
# Epoch 50/100
#  - 11s - loss: 3.7440e-04 - mean_squared_error: 3.7440e-04 - val_loss: 3.7414e-04 - val_mean_squared_error: 3.7414e-04
#
# Epoch 51/100
#  - 11s - loss: 3.7441e-04 - mean_squared_error: 3.7441e-04 - val_loss: 3.7305e-04 - val_mean_squared_error: 3.7305e-04
#
# Epoch 52/100
#  - 10s - loss: 3.7446e-04 - mean_squared_error: 3.7446e-04 - val_loss: 3.6945e-04 - val_mean_squared_error: 3.6945e-04
#
# Epoch 53/100
#  - 8s - loss: 3.7461e-04 - mean_squared_error: 3.7461e-04 - val_loss: 3.8361e-04 - val_mean_squared_error: 3.8361e-04
#
# Epoch 54/100
#  - 9s - loss: 3.7406e-04 - mean_squared_error: 3.7406e-04 - val_loss: 3.7028e-04 - val_mean_squared_error: 3.7028e-04
#
# Epoch 55/100
#  - 10s - loss: 3.7382e-04 - mean_squared_error: 3.7382e-04 - val_loss: 3.7452e-04 - val_mean_squared_error: 3.7452e-04
#
# Epoch 56/100
#  - 10s - loss: 3.7442e-04 - mean_squared_error: 3.7442e-04 - val_loss: 3.7762e-04 - val_mean_squared_error: 3.7762e-04
#
# Epoch 57/100
#  - 10s - loss: 3.7365e-04 - mean_squared_error: 3.7365e-04 - val_loss: 3.9438e-04 - val_mean_squared_error: 3.9438e-04
#
# Epoch 58/100
#  - 9s - loss: 3.7367e-04 - mean_squared_error: 3.7367e-04 - val_loss: 3.6690e-04 - val_mean_squared_error: 3.6690e-04
#
# Epoch 59/100
#  - 9s - loss: 3.7391e-04 - mean_squared_error: 3.7391e-04 - val_loss: 3.8273e-04 - val_mean_squared_error: 3.8273e-04
#
# Epoch 60/100
#  - 9s - loss: 3.7342e-04 - mean_squared_error: 3.7342e-04 - val_loss: 3.6741e-04 - val_mean_squared_error: 3.6741e-04
#
# Epoch 61/100
#  - 10s - loss: 3.7334e-04 - mean_squared_error: 3.7334e-04 - val_loss: 3.6492e-04 - val_mean_squared_error: 3.6492e-04
#
# Epoch 62/100
#  - 8s - loss: 3.7380e-04 - mean_squared_error: 3.7380e-04 - val_loss: 3.7306e-04 - val_mean_squared_error: 3.7306e-04
#
# Epoch 63/100
#  - 10s - loss: 3.7336e-04 - mean_squared_error: 3.7336e-04 - val_loss: 3.6896e-04 - val_mean_squared_error: 3.6896e-04
#
# Epoch 64/100
#  - 8s - loss: 3.7323e-04 - mean_squared_error: 3.7323e-04 - val_loss: 3.7347e-04 - val_mean_squared_error: 3.7347e-04
#
# Epoch 65/100
#  - 9s - loss: 3.7317e-04 - mean_squared_error: 3.7317e-04 - val_loss: 3.6636e-04 - val_mean_squared_error: 3.6636e-04
#
# Epoch 66/100
#  - 9s - loss: 3.7331e-04 - mean_squared_error: 3.7331e-04 - val_loss: 3.8623e-04 - val_mean_squared_error: 3.8623e-04
#
# Epoch 67/100
#  - 8s - loss: 3.7331e-04 - mean_squared_error: 3.7331e-04 - val_loss: 3.7011e-04 - val_mean_squared_error: 3.7011e-04
#
# Epoch 68/100
#  - 10s - loss: 3.7317e-04 - mean_squared_error: 3.7317e-04 - val_loss: 3.6834e-04 - val_mean_squared_error: 3.6834e-04
#
# Epoch 69/100
#  - 8s - loss: 3.7328e-04 - mean_squared_error: 3.7328e-04 - val_loss: 3.7741e-04 - val_mean_squared_error: 3.7741e-04
#
# Epoch 70/100
#  - 8s - loss: 3.7336e-04 - mean_squared_error: 3.7336e-04 - val_loss: 3.6877e-04 - val_mean_squared_error: 3.6877e-04
#
# Epoch 71/100
#  - 9s - loss: 3.7296e-04 - mean_squared_error: 3.7296e-04 - val_loss: 3.6729e-04 - val_mean_squared_error: 3.6729e-04
#
# Epoch 72/100
#  - 8s - loss: 3.7293e-04 - mean_squared_error: 3.7293e-04 - val_loss: 3.6774e-04 - val_mean_squared_error: 3.6774e-04
#
# Epoch 73/100
#  - 6s - loss: 3.7281e-04 - mean_squared_error: 3.7281e-04 - val_loss: 3.6412e-04 - val_mean_squared_error: 3.6412e-04
#
# Epoch 74/100
#  - 9s - loss: 3.7271e-04 - mean_squared_error: 3.7271e-04 - val_loss: 3.7240e-04 - val_mean_squared_error: 3.7240e-04
# Epoch 75/100
#  - 8s - loss: 3.7311e-04 - mean_squared_error: 3.7311e-04 - val_loss: 3.8184e-04 - val_mean_squared_error: 3.8184e-04
#
# Epoch 76/100
#  - 8s - loss: 3.7263e-04 - mean_squared_error: 3.7263e-04 - val_loss: 3.7863e-04 - val_mean_squared_error: 3.7863e-04
#
# Epoch 77/100
#  - 9s - loss: 3.7277e-04 - mean_squared_error: 3.7277e-04 - val_loss: 3.6868e-04 - val_mean_squared_error: 3.6868e-04
#
# Epoch 78/100
#  - 9s - loss: 3.7242e-04 - mean_squared_error: 3.7242e-04 - val_loss: 3.7693e-04 - val_mean_squared_error: 3.7693e-04
#
# Epoch 79/100
#  - 7s - loss: 3.7252e-04 - mean_squared_error: 3.7252e-04 - val_loss: 3.7519e-04 - val_mean_squared_error: 3.7519e-04
#
# Epoch 80/100
#  - 9s - loss: 3.7240e-04 - mean_squared_error: 3.7240e-04 - val_loss: 3.7580e-04 - val_mean_squared_error: 3.7580e-04
#
# Epoch 81/100
#  - 8s - loss: 3.7253e-04 - mean_squared_error: 3.7253e-04 - val_loss: 3.7000e-04 - val_mean_squared_error: 3.7000e-04
#
# Epoch 82/100
#  - 10s - loss: 3.7269e-04 - mean_squared_error: 3.7269e-04 - val_loss: 3.6873e-04 - val_mean_squared_error: 3.6873e-04
#
# Epoch 83/100
#  - 7s - loss: 3.7224e-04 - mean_squared_error: 3.7224e-04 - val_loss: 3.6949e-04 - val_mean_squared_error: 3.6949e-04
#
# Epoch 84/100
#  - 4s - loss: 3.7248e-04 - mean_squared_error: 3.7248e-04 - val_loss: 3.6526e-04 - val_mean_squared_error: 3.6526e-04
#
# Epoch 85/100
#  - 7s - loss: 3.7217e-04 - mean_squared_error: 3.7217e-04 - val_loss: 3.7700e-04 - val_mean_squared_error: 3.7700e-04
#
# Epoch 86/100
#  - 6s - loss: 3.7234e-04 - mean_squared_error: 3.7234e-04 - val_loss: 3.7688e-04 - val_mean_squared_error: 3.7688e-04
#
# Epoch 87/100
#  - 9s - loss: 3.7192e-04 - mean_squared_error: 3.7192e-04 - val_loss: 3.7089e-04 - val_mean_squared_error: 3.7089e-04
#
# Epoch 88/100
#  - 11s - loss: 3.7192e-04 - mean_squared_error: 3.7192e-04 - val_loss: 3.7384e-04 - val_mean_squared_error: 3.7384e-04
#
# Epoch 89/100
#  - 8s - loss: 3.7220e-04 - mean_squared_error: 3.7220e-04 - val_loss: 3.6403e-04 - val_mean_squared_error: 3.6403e-04
#
# Epoch 90/100
#  - 6s - loss: 3.7207e-04 - mean_squared_error: 3.7207e-04 - val_loss: 3.7106e-04 - val_mean_squared_error: 3.7106e-04
#
# Epoch 91/100
#  - 5s - loss: 3.7186e-04 - mean_squared_error: 3.7186e-04 - val_loss: 3.7722e-04 - val_mean_squared_error: 3.7722e-04
#
# Epoch 92/100
#  - 7s - loss: 3.7207e-04 - mean_squared_error: 3.7207e-04 - val_loss: 3.7308e-04 - val_mean_squared_error: 3.7308e-04
#
# Epoch 93/100
#  - 7s - loss: 3.7173e-04 - mean_squared_error: 3.7173e-04 - val_loss: 3.7027e-04 - val_mean_squared_error: 3.7027e-04
#
# Epoch 94/100
#  - 7s - loss: 3.7198e-04 - mean_squared_error: 3.7198e-04 - val_loss: 3.7275e-04 - val_mean_squared_error: 3.7275e-04
#
# Epoch 95/100
#  - 4s - loss: 3.7179e-04 - mean_squared_error: 3.7179e-04 - val_loss: 3.7358e-04 - val_mean_squared_error: 3.7358e-04
#
# Epoch 96/100
#  - 5s - loss: 3.7186e-04 - mean_squared_error: 3.7186e-04 - val_loss: 3.6799e-04 - val_mean_squared_error: 3.6799e-04
#
# Epoch 97/100
#  - 7s - loss: 3.7181e-04 - mean_squared_error: 3.7181e-04 - val_loss: 3.6925e-04 - val_mean_squared_error: 3.6925e-04
#
# Epoch 98/100
#  - 5s - loss: 3.7176e-04 - mean_squared_error: 3.7176e-04 - val_loss: 3.7004e-04 - val_mean_squared_error: 3.7004e-04
#
# Epoch 99/100
#  - 6s - loss: 3.7192e-04 - mean_squared_error: 3.7192e-04 - val_loss: 3.6887e-04 - val_mean_squared_error: 3.6887e-04
#
# Epoch 100/100
#  - 8s - loss: 3.7232e-04 - mean_squared_error: 3.7232e-04 - val_loss: 3.6921e-04 - val_mean_squared_error: 3.6921e-04
#
# Best validation loss of epoch:
# 0.0003640341338598066
# Train on 630000 samples, validate on 270000 samples
# Epoch 1/100
#  - 4s - loss: 6.1021e-04 - mean_squared_error: 6.1021e-04 - val_loss: 4.3023e-04 - val_mean_squared_error: 4.3023e-04
#
# Epoch 2/100
#  - 5s - loss: 4.2592e-04 - mean_squared_error: 4.2592e-04 - val_loss: 4.2130e-04 - val_mean_squared_error: 4.2130e-04
#
# Epoch 3/100
#  - 4s - loss: 4.1338e-04 - mean_squared_error: 4.1338e-04 - val_loss: 3.9656e-04 - val_mean_squared_error: 3.9656e-04
#
# Epoch 4/100
#  - 6s - loss: 4.0603e-04 - mean_squared_error: 4.0603e-04 - val_loss: 4.2037e-04 - val_mean_squared_error: 4.2037e-04
#
# Epoch 5/100
#  - 4s - loss: 4.0096e-04 - mean_squared_error: 4.0096e-04 - val_loss: 3.9832e-04 - val_mean_squared_error: 3.9832e-04
#
# Epoch 6/100
#  - 7s - loss: 3.9875e-04 - mean_squared_error: 3.9875e-04 - val_loss: 4.1813e-04 - val_mean_squared_error: 4.1813e-04
#
# Epoch 7/100
#  - 5s - loss: 3.9673e-04 - mean_squared_error: 3.9673e-04 - val_loss: 3.9365e-04 - val_mean_squared_error: 3.9365e-04
#
# Epoch 8/100
#  - 5s - loss: 3.9466e-04 - mean_squared_error: 3.9466e-04 - val_loss: 3.8020e-04 - val_mean_squared_error: 3.8020e-04
#
# Epoch 9/100
# ...
#
# Epoch 24/100
#  - 4s - loss: 4.8956e-04 - mean_squared_error: 4.8956e-04 - val_loss: 5.2234e-04 - val_mean_squared_error: 5.2234e-04
#
# Epoch 25/100
#  - 4s - loss: 4.8677e-04 - mean_squared_error: 4.8677e-04 - val_loss: 5.0441e-04 - val_mean_squared_error: 5.0441e-04
#
# Epoch 26/100
#  - 4s - loss: 4.8626e-04 - mean_squared_error: 4.8626e-04 - val_loss: 5.2528e-04 - val_mean_squared_error: 5.2528e-04
#
# Epoch 27/100
#  - 4s - loss: 4.9000e-04 - mean_squared_error: 4.9000e-04 - val_loss: 5.5905e-04 - val_mean_squared_error: 5.5905e-04
#
# Epoch 28/100
#  - 4s - loss: 4.8605e-04 - mean_squared_error: 4.8605e-04 - val_loss: 4.5744e-04 - val_mean_squared_error: 4.5744e-04
#
# Epoch 29/100
#  - 4s - loss: 4.8985e-04 - mean_squared_error: 4.8985e-04 - val_loss: 4.4442e-04 - val_mean_squared_error: 4.4442e-04
#
# Epoch 30/100
#  - 4s - loss: 4.8948e-04 - mean_squared_error: 4.8948e-04 - val_loss: 4.5497e-04 - val_mean_squared_error: 4.5497e-04
#
# Epoch 31/100
#  - 4s - loss: 4.9113e-04 - mean_squared_error: 4.9113e-04 - val_loss: 4.8473e-04 - val_mean_squared_error: 4.8473e-04
#
# Epoch 32/100
#  - 4s - loss: 4.8816e-04 - mean_squared_error: 4.8816e-04 - val_loss: 5.2260e-04 - val_mean_squared_error: 5.2260e-04
#
# Epoch 33/100
#  - 4s - loss: 4.8928e-04 - mean_squared_error: 4.8928e-04 - val_loss: 4.7920e-04 - val_mean_squared_error: 4.7920e-04
#
# Epoch 34/100
#  - 4s - loss: 4.8870e-04 - mean_squared_error: 4.8870e-04 - val_loss: 4.5161e-04 - val_mean_squared_error: 4.5161e-04
#
# Epoch 35/100
#  - 4s - loss: 4.8941e-04 - mean_squared_error: 4.8941e-04 - val_loss: 4.5688e-04 - val_mean_squared_error: 4.5688e-04
#
# Epoch 36/100
#  - 4s - loss: 4.8947e-04 - mean_squared_error: 4.8947e-04 - val_loss: 5.7331e-04 - val_mean_squared_error: 5.7331e-04
#
# Epoch 37/100
#  - 4s - loss: 4.8788e-04 - mean_squared_error: 4.8788e-04 - val_loss: 4.6819e-04 - val_mean_squared_error: 4.6819e-04
#
# Epoch 38/100
#  - 4s - loss: 4.8963e-04 - mean_squared_error: 4.8963e-04 - val_loss: 4.7401e-04 - val_mean_squared_error: 4.7401e-04
#
# Epoch 39/100
#  - 4s - loss: 4.8720e-04 - mean_squared_error: 4.8720e-04 - val_loss: 4.5793e-04 - val_mean_squared_error: 4.5793e-04
#
# Epoch 40/100
#  - 4s - loss: 4.8856e-04 - mean_squared_error: 4.8856e-04 - val_loss: 4.6477e-04 - val_mean_squared_error: 4.6477e-04
#
# Epoch 41/100
#  - 4s - loss: 4.8989e-04 - mean_squared_error: 4.8989e-04 - val_loss: 4.4564e-04 - val_mean_squared_error: 4.4564e-04
#
# Epoch 42/100
#  - 4s - loss: 4.9003e-04 - mean_squared_error: 4.9003e-04 - val_loss: 5.4560e-04 - val_mean_squared_error: 5.4560e-04
#
# Epoch 43/100
#  - 4s - loss: 4.9137e-04 - mean_squared_error: 4.9137e-04 - val_loss: 4.5449e-04 - val_mean_squared_error: 4.5449e-04
#
# Epoch 44/100
#  - 4s - loss: 4.8845e-04 - mean_squared_error: 4.8845e-04 - val_loss: 4.8325e-04 - val_mean_squared_error: 4.8325e-04
#
# Epoch 45/100
#  - 4s - loss: 4.8879e-04 - mean_squared_error: 4.8879e-04 - val_loss: 4.5155e-04 - val_mean_squared_error: 4.5155e-04
#
# Epoch 46/100
#  - 4s - loss: 4.8838e-04 - mean_squared_error: 4.8838e-04 - val_loss: 4.7720e-04 - val_mean_squared_error: 4.7720e-04
#
# Epoch 47/100
#  - 4s - loss: 4.9196e-04 - mean_squared_error: 4.9196e-04 - val_loss: 4.6487e-04 - val_mean_squared_error: 4.6487e-04
#
# Epoch 48/100
#  - 4s - loss: 4.8694e-04 - mean_squared_error: 4.8694e-04 - val_loss: 5.1899e-04 - val_mean_squared_error: 5.1899e-04
#
# Epoch 49/100
#  - 4s - loss: 4.8904e-04 - mean_squared_error: 4.8904e-04 - val_loss: 4.7399e-04 - val_mean_squared_error: 4.7399e-04
#
# Epoch 50/100
#  - 4s - loss: 4.8699e-04 - mean_squared_error: 4.8699e-04 - val_loss: 5.6426e-04 - val_mean_squared_error: 5.6426e-04
#
# Epoch 51/100
#  - 4s - loss: 4.8777e-04 - mean_squared_error: 4.8777e-04 - val_loss: 5.4068e-04 - val_mean_squared_error: 5.4068e-04
#
# Epoch 52/100
#  - 4s - loss: 4.8852e-04 - mean_squared_error: 4.8852e-04 - val_loss: 4.4834e-04 - val_mean_squared_error: 4.4834e-04
# Epoch 53/100
#  - 4s - loss: 4.8948e-04 - mean_squared_error: 4.8948e-04 - val_loss: 4.5526e-04 - val_mean_squared_error: 4.5526e-04
#
# Epoch 54/100
#  - 4s - loss: 4.8847e-04 - mean_squared_error: 4.8847e-04 - val_loss: 5.1068e-04 - val_mean_squared_error: 5.1068e-04
#
# Epoch 55/100
#  - 4s - loss: 4.8882e-04 - mean_squared_error: 4.8882e-04 - val_loss: 4.5419e-04 - val_mean_squared_error: 4.5419e-04
#
# Epoch 56/100
#  - 4s - loss: 4.8709e-04 - mean_squared_error: 4.8709e-04 - val_loss: 4.2594e-04 - val_mean_squared_error: 4.2594e-04
#
# Epoch 57/100
#  - 4s - loss: 4.8497e-04 - mean_squared_error: 4.8497e-04 - val_loss: 5.1951e-04 - val_mean_squared_error: 5.1951e-04
#
# Epoch 58/100
#  - 4s - loss: 4.8466e-04 - mean_squared_error: 4.8466e-04 - val_loss: 5.0536e-04 - val_mean_squared_error: 5.0536e-04
#
# Epoch 59/100
#  - 4s - loss: 4.8386e-04 - mean_squared_error: 4.8386e-04 - val_loss: 4.1459e-04 - val_mean_squared_error: 4.1459e-04
#
# Epoch 60/100
#  - 4s - loss: 4.8463e-04 - mean_squared_error: 4.8463e-04 - val_loss: 5.9397e-04 - val_mean_squared_error: 5.9397e-04
#
# Epoch 61/100
#  - 4s - loss: 4.8477e-04 - mean_squared_error: 4.8477e-04 - val_loss: 4.8632e-04 - val_mean_squared_error: 4.8632e-04
#
# Epoch 62/100
#  - 4s - loss: 4.8583e-04 - mean_squared_error: 4.8583e-04 - val_loss: 4.9213e-04 - val_mean_squared_error: 4.9213e-04
#
# Epoch 63/100
#  - 4s - loss: 4.8324e-04 - mean_squared_error: 4.8324e-04 - val_loss: 4.2119e-04 - val_mean_squared_error: 4.2119e-04
#
# Epoch 64/100
#  - 4s - loss: 4.8464e-04 - mean_squared_error: 4.8464e-04 - val_loss: 4.3356e-04 - val_mean_squared_error: 4.3356e-04
#
# Epoch 65/100
#  - 4s - loss: 4.8654e-04 - mean_squared_error: 4.8654e-04 - val_loss: 5.0698e-04 - val_mean_squared_error: 5.0698e-04
#
# Epoch 66/100
#  - 4s - loss: 4.8472e-04 - mean_squared_error: 4.8472e-04 - val_loss: 4.4761e-04 - val_mean_squared_error: 4.4761e-04
#
# Epoch 67/100
#  - 4s - loss: 4.8280e-04 - mean_squared_error: 4.8280e-04 - val_loss: 4.5273e-04 - val_mean_squared_error: 4.5273e-04
#
# Epoch 68/100
#  - 4s - loss: 4.8295e-04 - mean_squared_error: 4.8295e-04 - val_loss: 4.7050e-04 - val_mean_squared_error: 4.7050e-04
#
# Epoch 69/100
#  - 4s - loss: 4.8699e-04 - mean_squared_error: 4.8699e-04 - val_loss: 5.4299e-04 - val_mean_squared_error: 5.4299e-04
#
# Epoch 70/100
#  - 4s - loss: 4.8342e-04 - mean_squared_error: 4.8342e-04 - val_loss: 6.1475e-04 - val_mean_squared_error: 6.1475e-04
#
# Epoch 71/100
#  - 10s - loss: 4.8467e-04 - mean_squared_error: 4.8467e-04 - val_loss: 5.0532e-04 - val_mean_squared_error: 5.0532e-04
#
# Epoch 72/100
#  - 11s - loss: 4.8172e-04 - mean_squared_error: 4.8172e-04 - val_loss: 4.9769e-04 - val_mean_squared_error: 4.9769e-04
#
# Epoch 73/100
#  - 14s - loss: 4.8463e-04 - mean_squared_error: 4.8463e-04 - val_loss: 5.5438e-04 - val_mean_squared_error: 5.5438e-04
#
# Epoch 74/100
#  - 12s - loss: 4.8246e-04 - mean_squared_error: 4.8246e-04 - val_loss: 4.6648e-04 - val_mean_squared_error: 4.6648e-04
#
# Epoch 75/100
#  - 13s - loss: 4.8364e-04 - mean_squared_error: 4.8364e-04 - val_loss: 4.7267e-04 - val_mean_squared_error: 4.7267e-04
#
# Epoch 76/100
#  - 13s - loss: 4.8343e-04 - mean_squared_error: 4.8343e-04 - val_loss: 4.8949e-04 - val_mean_squared_error: 4.8949e-04
#
# Epoch 77/100
#  - 10s - loss: 4.8123e-04 - mean_squared_error: 4.8123e-04 - val_loss: 5.3949e-04 - val_mean_squared_error: 5.3949e-04
#
# Epoch 78/100
#  - 13s - loss: 4.8418e-04 - mean_squared_error: 4.8418e-04 - val_loss: 5.6094e-04 - val_mean_squared_error: 5.6094e-04
#
# Epoch 79/100
#  - 12s - loss: 4.8625e-04 - mean_squared_error: 4.8625e-04 - val_loss: 5.4010e-04 - val_mean_squared_error: 5.4010e-04
#
# Epoch 80/100
#  - 12s - loss: 4.8533e-04 - mean_squared_error: 4.8533e-04 - val_loss: 5.6344e-04 - val_mean_squared_error: 5.6344e-04
#
# Epoch 81/100
#  - 12s - loss: 4.8202e-04 - mean_squared_error: 4.8202e-04 - val_loss: 4.5578e-04 - val_mean_squared_error: 4.5578e-04
#
# Epoch 82/100
#  - 13s - loss: 4.8630e-04 - mean_squared_error: 4.8630e-04 - val_loss: 5.0254e-04 - val_mean_squared_error: 5.0254e-04
#
# Epoch 83/100
#  - 8s - loss: 4.8568e-04 - mean_squared_error: 4.8568e-04 - val_loss: 4.9012e-04 - val_mean_squared_error: 4.9012e-04
#
# Epoch 84/100
#  - 11s - loss: 4.8223e-04 - mean_squared_error: 4.8223e-04 - val_loss: 6.1430e-04 - val_mean_squared_error: 6.1430e-04
#
# Epoch 85/100
#  - 13s - loss: 4.8249e-04 - mean_squared_error: 4.8249e-04 - val_loss: 4.5754e-04 - val_mean_squared_error: 4.5754e-04
#
# Epoch 86/100
#  - 10s - loss: 4.8451e-04 - mean_squared_error: 4.8451e-04 - val_loss: 4.9349e-04 - val_mean_squared_error: 4.9349e-04
#
# Epoch 87/100
#  - 12s - loss: 4.8181e-04 - mean_squared_error: 4.8181e-04 - val_loss: 5.4997e-04 - val_mean_squared_error: 5.4997e-04
#
# Epoch 88/100
#  - 7s - loss: 4.8380e-04 - mean_squared_error: 4.8380e-04 - val_loss: 4.7176e-04 - val_mean_squared_error: 4.7176e-04
#
# Epoch 89/100
#  - 8s - loss: 4.8501e-04 - mean_squared_error: 4.8501e-04 - val_loss: 4.8643e-04 - val_mean_squared_error: 4.8643e-04
#
# Epoch 90/100
#  - 11s - loss: 4.8519e-04 - mean_squared_error: 4.8519e-04 - val_loss: 5.2289e-04 - val_mean_squared_error: 5.2289e-04
#
# Epoch 91/100
#  - 9s - loss: 4.8410e-04 - mean_squared_error: 4.8410e-04 - val_loss: 4.9083e-04 - val_mean_squared_error: 4.9083e-04
#
# Epoch 92/100
#  - 8s - loss: 4.8515e-04 - mean_squared_error: 4.8515e-04 - val_loss: 4.5864e-04 - val_mean_squared_error: 4.5864e-04
# Epoch 93/100
#  - 8s - loss: 4.8482e-04 - mean_squared_error: 4.8482e-04 - val_loss: 4.3175e-04 - val_mean_squared_error: 4.3175e-04
#
# Epoch 94/100
#  - 10s - loss: 4.8456e-04 - mean_squared_error: 4.8456e-04 - val_loss: 4.7728e-04 - val_mean_squared_error: 4.7728e-04
#
# Epoch 95/100
#  - 12s - loss: 4.8511e-04 - mean_squared_error: 4.8511e-04 - val_loss: 4.2759e-04 - val_mean_squared_error: 4.2759e-04
#
# Epoch 96/100
#  - 11s - loss: 4.8369e-04 - mean_squared_error: 4.8369e-04 - val_loss: 5.5359e-04 - val_mean_squared_error: 5.5359e-04
#
# Epoch 97/100
#  - 7s - loss: 4.8402e-04 - mean_squared_error: 4.8402e-04 - val_loss: 5.3279e-04 - val_mean_squared_error: 5.3279e-04
#
# Epoch 98/100
#  - 5s - loss: 4.8579e-04 - mean_squared_error: 4.8579e-04 - val_loss: 4.2975e-04 - val_mean_squared_error: 4.2975e-04
#
# Epoch 99/100
#  - 5s - loss: 4.8459e-04 - mean_squared_error: 4.8459e-04 - val_loss: 5.8778e-04 - val_mean_squared_error: 5.8778e-04
#
# Epoch 100/100
#  - 4s - loss: 4.8606e-04 - mean_squared_error: 4.8606e-04 - val_loss: 4.6757e-04 - val_mean_squared_error: 4.6757e-04
#
# Best validation loss of epoch:
# 0.00041458754415399634
# 100%|██████████| 20/20 [4:31:19<00:00, 626.80s/it, best loss: 0.000362854670470201]

# %%
X_train, Y_train, X_test, Y_test = data()
print("Evalutation of best performing model:")
print(best_model.evaluate(X_test, Y_test))
print("Best performing model chosen hyper-parameters:")
print(best_run)

best_model.save('best_model.h5')
# Out:
# /home/ab602/anaconda3/lib/python3.7/site-packages/uproot/tree.py:116: FutureWarning: Int64Index.data is deprecated and will be removed in a future version
#   index = awkward.numpy.frombuffer(arrays.index.data, dtype=arrays.index.dtype)
# Evalutation of best performing model:
# 100000/100000 [==============================] - 1s 10us/step
# [0.0003684300276171416, 0.0003684300276171416]
# Best performing model chosen hyper-parameters:
# {'lr': 0.0005}

# %%
## Save optimization results to txt file

fh = open("Optimization_results.txt", "w") 

fh.write("Evalutation of best performing model:\n")
fh.write(str(best_model.evaluate(X_test, Y_test))+"\n")
fh.write("Best performing model chosen hyper-parameters:\n")
fh.write(str(best_run)+"\n")
 
fh.close()
# Out:
# 100000/100000 [==============================] - 1s 10us/step
